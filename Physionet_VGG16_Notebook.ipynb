# %% [markdown]
# Author : _Sasika Amarasinghe_

# %% [markdown]
# ## Clone Repository

# %%
# !git clone https://github.com/IRS-UOM/vgg-16-cnn.git
# Out:
# fatal: destination path 'vgg-16-cnn' already exists and is not an empty directory.

# %%
# !pip install -r vgg-16-cnn/requirements.txt
# Out:
# Requirement already satisfied: joblib==1.3.2 in /usr/local/lib/python3.10/dist-packages (from -r vgg-16-cnn/requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: matplotlib==3.8.3 in /usr/local/lib/python3.10/dist-packages (from -r vgg-16-cnn/requirements.txt (line 2)) (3.8.3)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.10/dist-packages (from -r vgg-16-cnn/requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.10/dist-packages (from -r vgg-16-cnn/requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: pillow==10.3.0 in /usr/local/lib/python3.10/dist-packages (from -r vgg-16-cnn/requirements.txt (line 5)) (10.3.0)
# Requirement already satisfied: scikit-learn==1.4.2 in /usr/local/lib/python3.10/dist-packages (from -r vgg-16-cnn/requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: scipy==1.12.0 in /usr/local/lib/python3.10/dist-packages (from -r vgg-16-cnn/requirements.txt (line 7)) (1.12.0)
# Requirement already satisfied: seaborn==0.12.2 in /usr/local/lib/python3.10/dist-packages (from -r vgg-16-cnn/requirements.txt (line 8)) (0.12.2)
# Requirement already satisfied: tqdm==4.66.4 in /usr/local/lib/python3.10/dist-packages (from -r vgg-16-cnn/requirements.txt (line 9)) (4.66.4)
# Requirement already satisfied: wfdb==4.1.2 in /usr/local/lib/python3.10/dist-packages (from -r vgg-16-cnn/requirements.txt (line 10)) (4.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.3->-r vgg-16-cnn/requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.3->-r vgg-16-cnn/requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.3->-r vgg-16-cnn/requirements.txt (line 2)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.3->-r vgg-16-cnn/requirements.txt (line 2)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.3->-r vgg-16-cnn/requirements.txt (line 2)) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.3->-r vgg-16-cnn/requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.3->-r vgg-16-cnn/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2->-r vgg-16-cnn/requirements.txt (line 4)) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.2->-r vgg-16-cnn/requirements.txt (line 4)) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.4.2->-r vgg-16-cnn/requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb==4.1.2->-r vgg-16-cnn/requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from wfdb==4.1.2->-r vgg-16-cnn/requirements.txt (line 10)) (2.31.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.8.3->-r vgg-16-cnn/requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb==4.1.2->-r vgg-16-cnn/requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb==4.1.2->-r vgg-16-cnn/requirements.txt (line 10)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb==4.1.2->-r vgg-16-cnn/requirements.txt (line 10)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb==4.1.2->-r vgg-16-cnn/requirements.txt (line 10)) (2024.7.4)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb==4.1.2->-r vgg-16-cnn/requirements.txt (line 10)) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb==4.1.2->-r vgg-16-cnn/requirements.txt (line 10)) (2.22)

# %%
# !pip install wfdb==4.1.2

# %% [markdown]
# ## Download Dataset

# %%
# prompt: Download this "https://drive.google.com/file/d/1ZBC4vUCM2znV7ngAsigWnMkNdxoH7bMi/view?usp=drive_link" zip as train_data.zip

# !gdown --id 1ZBC4vUCM2znV7ngAsigWnMkNdxoH7bMi -O train_data.zip
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1ZBC4vUCM2znV7ngAsigWnMkNdxoH7bMi
# From (redirected): https://drive.google.com/uc?id=1ZBC4vUCM2znV7ngAsigWnMkNdxoH7bMi&confirm=t&uuid=7020b974-ff81-4347-91ef-d3118f18c32e
# To: /content/train_data.zip
# 100% 367M/367M [00:03<00:00, 103MB/s]

# %%
# prompt: unzip "/content/train_data.zip" to a folder "train_data"

# !unzip -j train_data.zip -d train_data_0
# Out:
# Archive:  train_data.zip
# replace train_data_0/00928_hr.dat? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: train_data_0/00928_hr.dat
#   inflating: train_data_0/00182_hr-0.png
#   inflating: train_data_0/00343_hr.hea
#   inflating: train_data_0/00426_hr.hea
#   inflating: train_data_0/00541_hr-0.png
#   inflating: train_data_0/00213_hr.dat
#   inflating: train_data_0/00323_hr.hea
#   inflating: train_data_0/00205_hr.hea
#   inflating: train_data_0/00699_hr.dat
#   inflating: train_data_0/00296_hr.dat
#   inflating: train_data_0/00558_hr-0.png
#   inflating: train_data_0/00600_hr.dat
#   inflating: train_data_0/00888_hr.dat
#   inflating: train_data_0/00678_hr.dat
#   inflating: train_data_0/00779_hr-0.png
#   inflating: train_data_0/00873_hr-0.png
#   inflating: train_data_0/00683_hr.dat
#   inflating: train_data_0/00250_hr-0.png
#   inflating: train_data_0/00801_hr.hea
#   inflating: train_data_0/00868_hr.dat
#   inflating: train_data_0/00394_hr.hea
#   inflating: train_data_0/00404_hr.dat
#   inflating: train_data_0/00559_hr-0.png
#   inflating: train_data_0/00627_hr.dat
#   inflating: train_data_0/00869_hr.hea
#   inflating: train_data_0/00705_hr-0.png
#   inflating: train_data_0/00854_hr.dat
#   inflating: train_data_0/00055_hr.dat
#   inflating: train_data_0/00822_hr.dat
#   inflating: train_data_0/00998_hr.hea
#   inflating: train_data_0/00074_hr.hea
#   inflating: train_data_0/00214_hr-0.png
#   inflating: train_data_0/00354_hr.dat
#   inflating: train_data_0/00837_hr.dat
#   inflating: train_data_0/00791_hr.dat
#   inflating: train_data_0/00983_hr.hea
#   inflating: train_data_0/00246_hr.dat
#   inflating: train_data_0/00872_hr.dat
#   inflating: train_data_0/00429_hr.hea
#   inflating: train_data_0/00045_hr.dat
#   inflating: train_data_0/00412_hr.dat
#   inflating: train_data_0/00162_hr.dat
#   inflating: train_data_0/00961_hr.hea
#   inflating: train_data_0/00165_hr.hea
#   inflating: train_data_0/00126_hr.hea
#   inflating: train_data_0/00997_hr-0.png
#   inflating: train_data_0/00516_hr.dat
#   inflating: train_data_0/00634_hr.hea
#   inflating: train_data_0/00680_hr.hea
#   inflating: train_data_0/00199_hr-0.png
#   inflating: train_data_0/00306_hr-0.png
#   inflating: train_data_0/00773_hr-0.png
#   inflating: train_data_0/00194_hr.hea
#   inflating: train_data_0/00870_hr.dat
#   inflating: train_data_0/00176_hr-0.png
#   inflating: train_data_0/00197_hr.dat
#   inflating: train_data_0/00464_hr-0.png
#   inflating: train_data_0/00489_hr-0.png
#   inflating: train_data_0/00531_hr.hea
#   inflating: train_data_0/00149_hr.hea
#   inflating: train_data_0/00180_hr.hea
#   inflating: train_data_0/00511_hr.dat
#   inflating: train_data_0/00908_hr.hea
#   inflating: train_data_0/00617_hr.hea
#   inflating: train_data_0/00826_hr.hea
#   inflating: train_data_0/00690_hr-0.png
#   inflating: train_data_0/00007_hr-0.png
#   inflating: train_data_0/00648_hr-0.png
#   inflating: train_data_0/00916_hr.dat
#   inflating: train_data_0/00788_hr.hea
#   inflating: train_data_0/00672_hr.dat
#   inflating: train_data_0/00637_hr.dat
#   inflating: train_data_0/00828_hr.hea
#   inflating: train_data_0/00597_hr.dat
#   inflating: train_data_0/00503_hr.dat
#   inflating: train_data_0/00721_hr.hea
#   inflating: train_data_0/00548_hr.dat
#   inflating: train_data_0/00034_hr.dat
#   inflating: train_data_0/00391_hr.hea
#   inflating: train_data_0/00084_hr-0.png
#   inflating: train_data_0/00495_hr-0.png
#   inflating: train_data_0/00656_hr-0.png
#   inflating: train_data_0/00944_hr.hea
#   inflating: train_data_0/00476_hr.dat
#   inflating: train_data_0/00884_hr.hea
#   inflating: train_data_0/00450_hr-0.png
#   inflating: train_data_0/00086_hr.hea
#   inflating: train_data_0/00365_hr-0.png
#   inflating: train_data_0/00710_hr-0.png
#   inflating: train_data_0/00239_hr.hea
#   inflating: train_data_0/00668_hr-0.png
#   inflating: train_data_0/00377_hr.hea
#   inflating: train_data_0/00099_hr.hea
#   inflating: train_data_0/00719_hr-0.png
#   inflating: train_data_0/00568_hr.dat
#   inflating: train_data_0/00048_hr-0.png
#   inflating: train_data_0/00239_hr.dat
#   inflating: train_data_0/00738_hr.hea
#   inflating: train_data_0/00331_hr-0.png
#   inflating: train_data_0/00898_hr-0.png
#   inflating: train_data_0/00283_hr-0.png
#   inflating: train_data_0/00473_hr.hea
#   inflating: train_data_0/00497_hr.dat
#   inflating: train_data_0/00453_hr.hea
#   inflating: train_data_0/00693_hr-0.png
#   inflating: train_data_0/00767_hr.hea
#   inflating: train_data_0/00077_hr.hea
#   inflating: train_data_0/00514_hr.hea
#   inflating: train_data_0/00374_hr.dat
#   inflating: train_data_0/00205_hr.dat
#   inflating: train_data_0/00326_hr-0.png
#   inflating: train_data_0/00714_hr.hea
#   inflating: train_data_0/00705_hr.hea
#   inflating: train_data_0/00902_hr.dat
#   inflating: train_data_0/00017_hr-0.png
#   inflating: train_data_0/00759_hr.dat
#   inflating: train_data_0/00326_hr.hea
#   inflating: train_data_0/00057_hr.hea
#   inflating: train_data_0/00807_hr.hea
#   inflating: train_data_0/00822_hr.hea
#   inflating: train_data_0/00664_hr.hea
#   inflating: train_data_0/00954_hr.dat
#   inflating: train_data_0/00328_hr-0.png
#   inflating: train_data_0/00048_hr.dat
#   inflating: train_data_0/00453_hr-0.png
#   inflating: train_data_0/00549_hr.dat
#   inflating: train_data_0/00315_hr.hea
#   inflating: train_data_0/00309_hr-0.png
#   inflating: train_data_0/00300_hr.hea
#   inflating: train_data_0/00754_hr.hea
#   inflating: train_data_0/00510_hr-0.png
#   inflating: train_data_0/00747_hr.hea
#   inflating: train_data_0/00359_hr-0.png
#   inflating: train_data_0/00159_hr.dat
#   inflating: train_data_0/00364_hr.hea
#   inflating: train_data_0/00942_hr.dat
#   inflating: train_data_0/00334_hr-0.png
#   inflating: train_data_0/00513_hr.hea
#   inflating: train_data_0/00128_hr.hea
#   inflating: train_data_0/00330_hr.dat
#   inflating: train_data_0/00007_hr.dat
#   inflating: train_data_0/00392_hr.hea
#   inflating: train_data_0/00094_hr.hea
#   inflating: train_data_0/00780_hr.dat
#   inflating: train_data_0/00512_hr.dat
#   inflating: train_data_0/00238_hr.dat
#   inflating: train_data_0/00661_hr-0.png
#   inflating: train_data_0/00761_hr.dat
#   inflating: train_data_0/00713_hr.dat
#   inflating: train_data_0/00363_hr.hea
#   inflating: train_data_0/00725_hr-0.png
#   inflating: train_data_0/00217_hr.dat
#   inflating: train_data_0/00502_hr.dat
#   inflating: train_data_0/00027_hr.dat
#   inflating: train_data_0/00640_hr-0.png
#   inflating: train_data_0/00361_hr-0.png
#   inflating: train_data_0/00558_hr.hea
#   inflating: train_data_0/00771_hr.hea
#   inflating: train_data_0/00231_hr.hea
#   inflating: train_data_0/00485_hr.hea
#   inflating: train_data_0/00691_hr.hea
#   inflating: train_data_0/00264_hr-0.png
#   inflating: train_data_0/00833_hr.dat
#   inflating: train_data_0/00615_hr.hea
#   inflating: train_data_0/00808_hr-0.png
#   inflating: train_data_0/00414_hr-0.png
#   inflating: train_data_0/00208_hr-0.png
#   inflating: train_data_0/00226_hr.dat
#   inflating: train_data_0/00837_hr.hea
#   inflating: train_data_0/00958_hr-0.png
#   inflating: train_data_0/00107_hr.hea
#   inflating: train_data_0/00971_hr-0.png
#   inflating: train_data_0/00757_hr.hea
#   inflating: train_data_0/00104_hr-0.png
#   inflating: train_data_0/00355_hr.dat
#   inflating: train_data_0/00310_hr.hea
#   inflating: train_data_0/00957_hr-0.png
#   inflating: train_data_0/00379_hr.hea
#   inflating: train_data_0/00739_hr.hea
#   inflating: train_data_0/00375_hr-0.png
#   inflating: train_data_0/00873_hr.dat
#   inflating: train_data_0/00302_hr-0.png
#   inflating: train_data_0/00341_hr-0.png
#   inflating: train_data_0/00918_hr.dat
#   inflating: train_data_0/00499_hr.dat
#   inflating: train_data_0/00643_hr.hea
#   inflating: train_data_0/00311_hr-0.png
#   inflating: train_data_0/00648_hr.hea
#   inflating: train_data_0/00047_hr.hea
#   inflating: train_data_0/00042_hr.dat
#   inflating: train_data_0/00904_hr.hea
#   inflating: train_data_0/00847_hr-0.png
#   inflating: train_data_0/00727_hr.hea
#   inflating: train_data_0/00260_hr.hea
#   inflating: train_data_0/00188_hr-0.png
#   inflating: train_data_0/00172_hr.hea
#   inflating: train_data_0/00934_hr.hea
#   inflating: train_data_0/00810_hr.hea
#   inflating: train_data_0/00382_hr-0.png
#   inflating: train_data_0/00740_hr-0.png
#   inflating: train_data_0/00610_hr-0.png
#   inflating: train_data_0/00917_hr.dat
#   inflating: train_data_0/00707_hr.hea
#   inflating: train_data_0/00133_hr.dat
#   inflating: train_data_0/00121_hr-0.png
#   inflating: train_data_0/00957_hr.hea
#   inflating: train_data_0/00336_hr.dat
#   inflating: train_data_0/00426_hr.dat
#   inflating: train_data_0/00160_hr.hea
#   inflating: train_data_0/00830_hr.hea
#   inflating: train_data_0/00424_hr-0.png
#   inflating: train_data_0/00930_hr.dat
#   inflating: train_data_0/00153_hr.dat
#   inflating: train_data_0/00435_hr.dat
#   inflating: train_data_0/00356_hr.hea
#   inflating: train_data_0/00353_hr.hea
#   inflating: train_data_0/00408_hr.hea
#   inflating: train_data_0/00617_hr.dat
#   inflating: train_data_0/00125_hr.dat
#   inflating: train_data_0/00156_hr.hea
#   inflating: train_data_0/00565_hr.hea
#   inflating: train_data_0/00081_hr.dat
#   inflating: train_data_0/00994_hr-0.png
#   inflating: train_data_0/00154_hr-0.png
#   inflating: train_data_0/00797_hr.dat
#   inflating: train_data_0/00468_hr.dat
#   inflating: train_data_0/00890_hr-0.png
#   inflating: train_data_0/00563_hr-0.png
#   inflating: train_data_0/00453_hr.dat
#   inflating: train_data_0/00508_hr.dat
#   inflating: train_data_0/00797_hr.hea
#   inflating: train_data_0/00114_hr-0.png
#   inflating: train_data_0/00123_hr.dat
#   inflating: train_data_0/00910_hr.hea
#   inflating: train_data_0/00393_hr.dat
#   inflating: train_data_0/00085_hr.dat
#   inflating: train_data_0/00684_hr.dat
#   inflating: train_data_0/00838_hr-0.png
#   inflating: train_data_0/00213_hr.hea
#   inflating: train_data_0/00055_hr-0.png
#   inflating: train_data_0/00207_hr.hea
#   inflating: train_data_0/00199_hr.dat
#   inflating: train_data_0/00118_hr.dat
#   inflating: train_data_0/00223_hr-0.png
#   inflating: train_data_0/00173_hr.hea
#   inflating: train_data_0/00487_hr-0.png
#   inflating: train_data_0/00739_hr.dat
#   inflating: train_data_0/00225_hr.dat
#   inflating: train_data_0/00914_hr-0.png
#   inflating: train_data_0/00076_hr.hea
#   inflating: train_data_0/00660_hr-0.png
#   inflating: train_data_0/00758_hr.dat
#   inflating: train_data_0/00704_hr-0.png
#   inflating: train_data_0/00025_hr.hea
#   inflating: train_data_0/00218_hr-0.png
#   inflating: train_data_0/00604_hr.hea
#   inflating: train_data_0/00520_hr.hea
#   inflating: train_data_0/00376_hr.hea
#   inflating: train_data_0/00256_hr.hea
#   inflating: train_data_0/00235_hr.dat
#   inflating: train_data_0/00310_hr-0.png
#   inflating: train_data_0/00019_hr.dat
#   inflating: train_data_0/00990_hr.hea
#   inflating: train_data_0/00915_hr-0.png
#   inflating: train_data_0/00331_hr.dat
#   inflating: train_data_0/00043_hr.hea
#   inflating: train_data_0/00646_hr.hea
#   inflating: train_data_0/00317_hr-0.png
#   inflating: train_data_0/00688_hr.dat
#   inflating: train_data_0/00259_hr.dat
#   inflating: train_data_0/00228_hr-0.png
#   inflating: train_data_0/00828_hr.dat
#   inflating: train_data_0/00062_hr.hea
#   inflating: train_data_0/00697_hr.hea
#   inflating: train_data_0/00421_hr.dat
#   inflating: train_data_0/00074_hr-0.png
#   inflating: train_data_0/00755_hr-0.png
#   inflating: train_data_0/00530_hr-0.png
#   inflating: train_data_0/00682_hr-0.png
#   inflating: train_data_0/00047_hr.dat
#   inflating: train_data_0/00319_hr.hea
#   inflating: train_data_0/00839_hr-0.png
#   inflating: train_data_0/00531_hr-0.png
#   inflating: train_data_0/00654_hr.dat
#   inflating: train_data_0/00215_hr.hea
#   inflating: train_data_0/00962_hr.hea
#   inflating: train_data_0/00686_hr.dat
#   inflating: train_data_0/00232_hr-0.png
#   inflating: train_data_0/00135_hr.hea
#   inflating: train_data_0/00564_hr.hea
#   inflating: train_data_0/00866_hr.hea
#   inflating: train_data_0/00638_hr-0.png
#   inflating: train_data_0/00830_hr.dat
#   inflating: train_data_0/00035_hr.dat
#   inflating: train_data_0/00525_hr.hea
#   inflating: train_data_0/00073_hr.hea
#   inflating: train_data_0/00397_hr.dat
#   inflating: train_data_0/00954_hr-0.png
#   inflating: train_data_0/00210_hr.dat
#   inflating: train_data_0/00780_hr-0.png
#   inflating: train_data_0/00902_hr.hea
#   inflating: train_data_0/00521_hr.hea
#   inflating: train_data_0/00211_hr-0.png
#   inflating: train_data_0/00181_hr-0.png
#   inflating: train_data_0/00466_hr-0.png
#   inflating: train_data_0/00014_hr.dat
#   inflating: train_data_0/00282_hr-0.png
#   inflating: train_data_0/00030_hr.hea
#   inflating: train_data_0/00519_hr.dat
#   inflating: train_data_0/00778_hr.hea
#   inflating: train_data_0/00125_hr-0.png
#   inflating: train_data_0/00889_hr.hea
#   inflating: train_data_0/00815_hr-0.png
#   inflating: train_data_0/00358_hr.dat
#   inflating: train_data_0/00666_hr.hea
#   inflating: train_data_0/00502_hr.hea
#   inflating: train_data_0/00709_hr.hea
#   inflating: train_data_0/00604_hr-0.png
#   inflating: train_data_0/00434_hr.hea
#   inflating: train_data_0/00352_hr.hea
#   inflating: train_data_0/00001_hr-0.png
#   inflating: train_data_0/00814_hr.hea
#   inflating: train_data_0/00204_hr.hea
#   inflating: train_data_0/00303_hr.dat
#   inflating: train_data_0/00109_hr.dat
#   inflating: train_data_0/00278_hr.dat
#   inflating: train_data_0/00603_hr.hea
#   inflating: train_data_0/00305_hr.dat
#   inflating: train_data_0/00058_hr.hea
#   inflating: train_data_0/00919_hr-0.png
#   inflating: train_data_0/00923_hr.dat
#   inflating: train_data_0/00108_hr-0.png
#   inflating: train_data_0/00671_hr.hea
#   inflating: train_data_0/00219_hr.hea
#   inflating: train_data_0/00993_hr.dat
#   inflating: train_data_0/00008_hr.hea
#   inflating: train_data_0/00410_hr.hea
#   inflating: train_data_0/00668_hr.hea
#   inflating: train_data_0/00110_hr-0.png
#   inflating: train_data_0/00265_hr.dat
#   inflating: train_data_0/00018_hr-0.png
#   inflating: train_data_0/00519_hr-0.png
#   inflating: train_data_0/00224_hr-0.png
#   inflating: train_data_0/00851_hr.hea
#   inflating: train_data_0/00038_hr.hea
#   inflating: train_data_0/00429_hr.dat
#   inflating: train_data_0/00138_hr-0.png
#   inflating: train_data_0/00978_hr.hea
#   inflating: train_data_0/00586_hr.hea
#   inflating: train_data_0/00109_hr.hea
#   inflating: train_data_0/00275_hr-0.png
#   inflating: train_data_0/00056_hr.dat
#   inflating: train_data_0/00739_hr-0.png
#   inflating: train_data_0/00703_hr.hea
#   inflating: train_data_0/00193_hr.hea
#   inflating: train_data_0/00191_hr.dat
#   inflating: train_data_0/00038_hr-0.png
#   inflating: train_data_0/00337_hr.dat
#   inflating: train_data_0/00263_hr.dat
#   inflating: train_data_0/00572_hr.hea
#   inflating: train_data_0/00626_hr-0.png
#   inflating: train_data_0/00413_hr.dat
#   inflating: train_data_0/00291_hr-0.png
#   inflating: train_data_0/00161_hr.dat
#   inflating: train_data_0/00314_hr-0.png
#   inflating: train_data_0/00695_hr-0.png
#   inflating: train_data_0/00747_hr-0.png
#   inflating: train_data_0/00753_hr-0.png
#   inflating: train_data_0/00774_hr.dat
#   inflating: train_data_0/00666_hr-0.png
#   inflating: train_data_0/00202_hr.dat
#   inflating: train_data_0/00753_hr.dat
#   inflating: train_data_0/00736_hr-0.png
#   inflating: train_data_0/00420_hr-0.png
#   inflating: train_data_0/00964_hr.hea
#   inflating: train_data_0/00164_hr-0.png
#   inflating: train_data_0/00473_hr-0.png
#   inflating: train_data_0/00777_hr.hea
#   inflating: train_data_0/00920_hr.hea
#   inflating: train_data_0/00849_hr.dat
#   inflating: train_data_0/00628_hr.hea
#   inflating: train_data_0/00575_hr.hea
#   inflating: train_data_0/00333_hr-0.png
#   inflating: train_data_0/00577_hr.dat
#   inflating: train_data_0/00840_hr.dat
#   inflating: train_data_0/00593_hr-0.png
#   inflating: train_data_0/00161_hr-0.png
#   inflating: train_data_0/00484_hr.dat
#   inflating: train_data_0/00348_hr-0.png
#   inflating: train_data_0/00431_hr-0.png
#   inflating: train_data_0/00199_hr.hea
#   inflating: train_data_0/00313_hr-0.png
#   inflating: train_data_0/00941_hr-0.png
#   inflating: train_data_0/00849_hr-0.png
#   inflating: train_data_0/00570_hr.hea
#   inflating: train_data_0/00669_hr.hea
#   inflating: train_data_0/00612_hr.dat
#   inflating: train_data_0/00786_hr.dat
#   inflating: train_data_0/00349_hr.dat
#   inflating: train_data_0/00981_hr-0.png
#   inflating: train_data_0/00580_hr-0.png
#   inflating: train_data_0/00718_hr-0.png
#   inflating: train_data_0/00403_hr.dat
#   inflating: train_data_0/00070_hr.dat
#   inflating: train_data_0/00741_hr-0.png
#   inflating: train_data_0/00735_hr.hea
#   inflating: train_data_0/00841_hr.dat
#   inflating: train_data_0/00530_hr.hea
#   inflating: train_data_0/00312_hr.hea
#   inflating: train_data_0/00283_hr.dat
#   inflating: train_data_0/00004_hr.hea
#   inflating: train_data_0/00880_hr.hea
#   inflating: train_data_0/00554_hr.dat
#   inflating: train_data_0/00975_hr-0.png
#   inflating: train_data_0/00240_hr.hea
#   inflating: train_data_0/00885_hr-0.png
#   inflating: train_data_0/00254_hr.hea
#   inflating: train_data_0/00953_hr.hea
#   inflating: train_data_0/00881_hr-0.png
#   inflating: train_data_0/00601_hr.hea
#   inflating: train_data_0/00883_hr.hea
#   inflating: train_data_0/00016_hr.dat
#   inflating: train_data_0/00411_hr.hea
#   inflating: train_data_0/00151_hr.dat
#   inflating: train_data_0/00490_hr.hea
#   inflating: train_data_0/00937_hr.dat
#   inflating: train_data_0/00094_hr.dat
#   inflating: train_data_0/00535_hr.hea
#   inflating: train_data_0/00939_hr.hea
#   inflating: train_data_0/00616_hr.dat
#   inflating: train_data_0/00344_hr.hea
#   inflating: train_data_0/00281_hr.dat
#   inflating: train_data_0/00719_hr.hea
#   inflating: train_data_0/00003_hr.hea
#   inflating: train_data_0/00563_hr.dat
#   inflating: train_data_0/00820_hr-0.png
#   inflating: train_data_0/00540_hr.hea
#   inflating: train_data_0/00149_hr.dat
#   inflating: train_data_0/00112_hr.hea
#   inflating: train_data_0/00827_hr-0.png
#   inflating: train_data_0/00821_hr.dat
#   inflating: train_data_0/00596_hr-0.png
#   inflating: train_data_0/00324_hr-0.png
#   inflating: train_data_0/00827_hr.hea
#   inflating: train_data_0/00872_hr-0.png
#   inflating: train_data_0/00952_hr-0.png
#   inflating: train_data_0/00675_hr.hea
#   inflating: train_data_0/00965_hr.dat
#   inflating: train_data_0/00076_hr.dat
#   inflating: train_data_0/00217_hr.hea
#   inflating: train_data_0/00651_hr.hea
#   inflating: train_data_0/00933_hr.hea
#   inflating: train_data_0/00097_hr.hea
#   inflating: train_data_0/00725_hr.dat
#   inflating: train_data_0/00793_hr.dat
#   inflating: train_data_0/00405_hr-0.png
#   inflating: train_data_0/00708_hr-0.png
#   inflating: train_data_0/00656_hr.hea
#   inflating: train_data_0/00745_hr.dat
#   inflating: train_data_0/00069_hr.hea
#   inflating: train_data_0/00245_hr.dat
#   inflating: train_data_0/00812_hr-0.png
#   inflating: train_data_0/00522_hr-0.png
#   inflating: train_data_0/00392_hr.dat
#   inflating: train_data_0/00712_hr-0.png
#   inflating: train_data_0/00123_hr-0.png
#   inflating: train_data_0/00580_hr.hea
#   inflating: train_data_0/00253_hr-0.png
#   inflating: train_data_0/00935_hr.hea
#   inflating: train_data_0/00017_hr.hea
#   inflating: train_data_0/00280_hr.hea
#   inflating: train_data_0/00826_hr-0.png
#   inflating: train_data_0/00471_hr.dat
#   inflating: train_data_0/00153_hr-0.png
#   inflating: train_data_0/00333_hr.dat
#   inflating: train_data_0/00784_hr.hea
#   inflating: train_data_0/00930_hr.hea
#   inflating: train_data_0/00992_hr-0.png
#   inflating: train_data_0/00677_hr.hea
#   inflating: train_data_0/00996_hr.dat
#   inflating: train_data_0/00689_hr-0.png
#   inflating: train_data_0/00663_hr-0.png
#   inflating: train_data_0/00790_hr.hea
#   inflating: train_data_0/00980_hr.dat
#   inflating: train_data_0/00381_hr.dat
#   inflating: train_data_0/00734_hr.dat
#   inflating: train_data_0/00097_hr-0.png
#   inflating: train_data_0/00914_hr.dat
#   inflating: train_data_0/00297_hr.hea
#   inflating: train_data_0/00809_hr-0.png
#   inflating: train_data_0/00186_hr-0.png
#   inflating: train_data_0/00353_hr-0.png
#   inflating: train_data_0/00348_hr.dat
#   inflating: train_data_0/00478_hr-0.png
#   inflating: train_data_0/00091_hr-0.png
#   inflating: train_data_0/00828_hr-0.png
#   inflating: train_data_0/00181_hr.dat
#   inflating: train_data_0/00125_hr.hea
#   inflating: train_data_0/00550_hr-0.png
#   inflating: train_data_0/00906_hr.hea
#   inflating: train_data_0/00881_hr.dat
#   inflating: train_data_0/00696_hr-0.png
#   inflating: train_data_0/00604_hr.dat
#   inflating: train_data_0/00921_hr.hea
#   inflating: train_data_0/00343_hr.dat
#   inflating: train_data_0/00060_hr.dat
#   inflating: train_data_0/00245_hr.hea
#   inflating: train_data_0/00653_hr.hea
#   inflating: train_data_0/00697_hr-0.png
#   inflating: train_data_0/00197_hr.hea
#   inflating: train_data_0/00511_hr.hea
#   inflating: train_data_0/00408_hr.dat
#   inflating: train_data_0/00180_hr.dat
#   inflating: train_data_0/00750_hr.dat
#   inflating: train_data_0/00132_hr.hea
#   inflating: train_data_0/00913_hr.hea
#   inflating: train_data_0/00383_hr-0.png
#   inflating: train_data_0/00168_hr-0.png
#   inflating: train_data_0/00813_hr-0.png
#   inflating: train_data_0/00806_hr.dat
#   inflating: train_data_0/00408_hr-0.png
#   inflating: train_data_0/00970_hr.hea
#   inflating: train_data_0/00433_hr.dat
#   inflating: train_data_0/00823_hr.hea
#   inflating: train_data_0/00298_hr.dat
#   inflating: train_data_0/00106_hr.hea
#   inflating: train_data_0/00592_hr.dat
#   inflating: train_data_0/00551_hr-0.png
#   inflating: train_data_0/00671_hr-0.png
#   inflating: train_data_0/00244_hr.dat
#   inflating: train_data_0/00605_hr.dat
#   inflating: train_data_0/00920_hr.dat
#   inflating: train_data_0/00571_hr.dat
#   inflating: train_data_0/00526_hr-0.png
#   inflating: train_data_0/00311_hr.dat
#   inflating: train_data_0/00734_hr-0.png
#   inflating: train_data_0/00444_hr-0.png
#   inflating: train_data_0/00249_hr-0.png
#   inflating: train_data_0/00350_hr.dat
#   inflating: train_data_0/00083_hr.hea
#   inflating: train_data_0/00507_hr-0.png
#   inflating: train_data_0/00371_hr.hea
#   inflating: train_data_0/00852_hr.dat
#   inflating: train_data_0/00686_hr.hea
#   inflating: train_data_0/00700_hr.dat
#   inflating: train_data_0/00065_hr.dat
#   inflating: train_data_0/00063_hr-0.png
#   inflating: train_data_0/00124_hr-0.png
#   inflating: train_data_0/00273_hr-0.png
#   inflating: train_data_0/00798_hr.hea
#   inflating: train_data_0/00031_hr-0.png
#   inflating: train_data_0/00861_hr.hea
#   inflating: train_data_0/00655_hr.dat
#   inflating: train_data_0/00824_hr.dat
#   inflating: train_data_0/00475_hr.hea
#   inflating: train_data_0/00485_hr.dat
#   inflating: train_data_0/00018_hr.hea
#   inflating: train_data_0/00975_hr.hea
#   inflating: train_data_0/00441_hr.hea
#   inflating: train_data_0/00620_hr-0.png
#   inflating: train_data_0/00375_hr.hea
#   inflating: train_data_0/00332_hr.hea
#   inflating: train_data_0/00404_hr.hea
#   inflating: train_data_0/00691_hr-0.png
#   inflating: train_data_0/00396_hr-0.png
#   inflating: train_data_0/00186_hr.hea
#   inflating: train_data_0/00594_hr.dat
#   inflating: train_data_0/00486_hr.dat
#   inflating: train_data_0/00370_hr.dat
#   inflating: train_data_0/00665_hr.hea
#   inflating: train_data_0/00505_hr.hea
#   inflating: train_data_0/00086_hr.dat
#   inflating: train_data_0/00225_hr-0.png
#   inflating: train_data_0/00804_hr.hea
#   inflating: train_data_0/00542_hr.dat
#   inflating: train_data_0/00709_hr.dat
#   inflating: train_data_0/00980_hr.hea
#   inflating: train_data_0/00250_hr.dat
#   inflating: train_data_0/00136_hr-0.png
#   inflating: train_data_0/00474_hr.hea
#   inflating: train_data_0/00644_hr.hea
#   inflating: train_data_0/00795_hr.dat
#   inflating: train_data_0/00575_hr-0.png
#   inflating: train_data_0/00720_hr-0.png
#   inflating: train_data_0/00524_hr.hea
#   inflating: train_data_0/00749_hr.dat
#   inflating: train_data_0/00792_hr.hea
#   inflating: train_data_0/00117_hr.hea
#   inflating: train_data_0/00703_hr.dat
#   inflating: train_data_0/00108_hr.hea
#   inflating: train_data_0/00044_hr.hea
#   inflating: train_data_0/00288_hr.dat
#   inflating: train_data_0/00370_hr-0.png
#   inflating: train_data_0/00787_hr.dat
#   inflating: train_data_0/00841_hr.hea
#   inflating: train_data_0/00243_hr.dat
#   inflating: train_data_0/00058_hr.dat
#   inflating: train_data_0/00892_hr.dat
#   inflating: train_data_0/00965_hr.hea
#   inflating: train_data_0/00773_hr.hea
#   inflating: train_data_0/00834_hr.dat
#   inflating: train_data_0/00803_hr.dat
#   inflating: train_data_0/00441_hr.dat
#   inflating: train_data_0/00854_hr.hea
#   inflating: train_data_0/00012_hr-0.png
#   inflating: train_data_0/00425_hr.hea
#   inflating: train_data_0/00552_hr.hea
#   inflating: train_data_0/00084_hr.hea
#   inflating: train_data_0/00398_hr-0.png
#   inflating: train_data_0/00895_hr.hea
#   inflating: train_data_0/00243_hr.hea
#   inflating: train_data_0/00980_hr-0.png
#   inflating: train_data_0/00949_hr-0.png
#   inflating: train_data_0/00580_hr.dat
#   inflating: train_data_0/00227_hr.dat
#   inflating: train_data_0/00167_hr.dat
#   inflating: train_data_0/00410_hr-0.png
#   inflating: train_data_0/00896_hr.hea
#   inflating: train_data_0/00774_hr-0.png
#   inflating: train_data_0/00224_hr.hea
#   inflating: train_data_0/00519_hr.hea
#   inflating: train_data_0/00215_hr.dat
#   inflating: train_data_0/00802_hr-0.png
#   inflating: train_data_0/00318_hr-0.png
#   inflating: train_data_0/00905_hr.hea
#   inflating: train_data_0/00403_hr.hea
#   inflating: train_data_0/00715_hr-0.png
#   inflating: train_data_0/00399_hr.dat
#   inflating: train_data_0/00135_hr.dat
#   inflating: train_data_0/00693_hr.hea
#   inflating: train_data_0/00386_hr.hea
#   inflating: train_data_0/00059_hr.dat
#   inflating: train_data_0/00330_hr-0.png
#   inflating: train_data_0/00179_hr.hea
#   inflating: train_data_0/00489_hr.hea
#   inflating: train_data_0/00637_hr.hea
#   inflating: train_data_0/00586_hr.dat
#   inflating: train_data_0/00887_hr-0.png
#   inflating: train_data_0/00299_hr.hea
#   inflating: train_data_0/00090_hr.dat
#   inflating: train_data_0/00164_hr.hea
#   inflating: train_data_0/00335_hr.dat
#   inflating: train_data_0/00573_hr.hea
#   inflating: train_data_0/00853_hr.hea
#   inflating: train_data_0/00409_hr.dat
#   inflating: train_data_0/00344_hr-0.png
#   inflating: train_data_0/00958_hr.dat
#   inflating: train_data_0/00532_hr.hea
#   inflating: train_data_0/00308_hr.dat
#   inflating: train_data_0/00006_hr.dat
#   inflating: train_data_0/00919_hr.hea
#   inflating: train_data_0/00044_hr.dat
#   inflating: train_data_0/00659_hr.dat
#   inflating: train_data_0/00630_hr.hea
#   inflating: train_data_0/00864_hr.dat
#   inflating: train_data_0/00080_hr.dat
#   inflating: train_data_0/00755_hr.hea
#   inflating: train_data_0/00203_hr.dat
#   inflating: train_data_0/00850_hr.dat
#   inflating: train_data_0/00395_hr.hea
#   inflating: train_data_0/00799_hr.dat
#   inflating: train_data_0/00184_hr.hea
#   inflating: train_data_0/00818_hr.dat
#   inflating: train_data_0/00415_hr.hea
#   inflating: train_data_0/00175_hr.hea
#   inflating: train_data_0/00972_hr.dat
#   inflating: train_data_0/00296_hr-0.png
#   inflating: train_data_0/00201_hr.dat
#   inflating: train_data_0/00046_hr-0.png
#   inflating: train_data_0/00710_hr.dat
#   inflating: train_data_0/00742_hr.dat
#   inflating: train_data_0/00315_hr.dat
#   inflating: train_data_0/00657_hr.hea
#   inflating: train_data_0/00682_hr.dat
#   inflating: train_data_0/00614_hr.hea
#   inflating: train_data_0/00893_hr-0.png
#   inflating: train_data_0/00724_hr.dat
#   inflating: train_data_0/00639_hr-0.png
#   inflating: train_data_0/00376_hr-0.png
#   inflating: train_data_0/00303_hr.hea
#   inflating: train_data_0/00763_hr-0.png
#   inflating: train_data_0/00674_hr-0.png
#   inflating: train_data_0/00197_hr-0.png
#   inflating: train_data_0/00506_hr.dat
#   inflating: train_data_0/00056_hr.hea
#   inflating: train_data_0/00500_hr.hea
#   inflating: train_data_0/00742_hr-0.png
#   inflating: train_data_0/00115_hr.dat
#   inflating: train_data_0/00138_hr.hea
#   inflating: train_data_0/00882_hr.hea
#   inflating: train_data_0/00811_hr-0.png
#   inflating: train_data_0/00232_hr.dat
#   inflating: train_data_0/00989_hr.hea
#   inflating: train_data_0/00600_hr-0.png
#   inflating: train_data_0/00912_hr.dat
#   inflating: train_data_0/00933_hr.dat
#   inflating: train_data_0/00015_hr.dat
#   inflating: train_data_0/00072_hr.hea
#   inflating: train_data_0/00987_hr-0.png
#   inflating: train_data_0/00385_hr-0.png
#   inflating: train_data_0/00633_hr-0.png
#   inflating: train_data_0/00296_hr.hea
#   inflating: train_data_0/00618_hr.hea
#   inflating: train_data_0/00907_hr-0.png
#   inflating: train_data_0/00454_hr.dat
#   inflating: train_data_0/00520_hr.dat
#   inflating: train_data_0/00306_hr.hea
#   inflating: train_data_0/00940_hr.dat
#   inflating: train_data_0/00596_hr.dat
#   inflating: train_data_0/00677_hr-0.png
#   inflating: train_data_0/00061_hr.hea
#   inflating: train_data_0/00387_hr.dat
#   inflating: train_data_0/00050_hr.hea
#   inflating: train_data_0/00968_hr.dat
#   inflating: train_data_0/00248_hr.hea
#   inflating: train_data_0/00219_hr-0.png
#   inflating: train_data_0/00221_hr.hea
#   inflating: train_data_0/00191_hr.hea
#   inflating: train_data_0/00514_hr.dat
#   inflating: train_data_0/00414_hr.hea
#   inflating: train_data_0/00474_hr-0.png
#   inflating: train_data_0/00550_hr.dat
#   inflating: train_data_0/00327_hr.hea
#   inflating: train_data_0/00579_hr-0.png
#   inflating: train_data_0/00863_hr.dat
#   inflating: train_data_0/00571_hr.hea
#   inflating: train_data_0/00816_hr.dat
#   inflating: train_data_0/00254_hr.dat
#   inflating: train_data_0/00014_hr-0.png
#   inflating: train_data_0/00275_hr.dat
#   inflating: train_data_0/00486_hr-0.png
#   inflating: train_data_0/00934_hr-0.png
#   inflating: train_data_0/00829_hr-0.png
#   inflating: train_data_0/00074_hr.dat
#   inflating: train_data_0/00355_hr.hea
#   inflating: train_data_0/00961_hr-0.png
#   inflating: train_data_0/00445_hr.hea
#   inflating: train_data_0/00820_hr.dat
#   inflating: train_data_0/00740_hr.hea
#   inflating: train_data_0/00325_hr.hea
#   inflating: train_data_0/00223_hr.dat
#   inflating: train_data_0/00248_hr-0.png
#   inflating: train_data_0/00087_hr-0.png
#   inflating: train_data_0/00876_hr.hea
#   inflating: train_data_0/00013_hr-0.png
#   inflating: train_data_0/00478_hr.dat
#   inflating: train_data_0/00911_hr.dat
#   inflating: train_data_0/00874_hr-0.png
#   inflating: train_data_0/00470_hr-0.png
#   inflating: train_data_0/00110_hr.dat
#   inflating: train_data_0/00904_hr-0.png
#   inflating: train_data_0/00548_hr.hea
#   inflating: train_data_0/00852_hr.hea
#   inflating: train_data_0/00481_hr.dat
#   inflating: train_data_0/00359_hr.hea
#   inflating: train_data_0/00836_hr-0.png
#   inflating: train_data_0/00152_hr.hea
#   inflating: train_data_0/00641_hr.dat
#   inflating: train_data_0/00746_hr.dat
#   inflating: train_data_0/00538_hr.dat
#   inflating: train_data_0/00262_hr-0.png
#   inflating: train_data_0/00364_hr-0.png
#   inflating: train_data_0/00265_hr-0.png
#   inflating: train_data_0/00529_hr.hea
#   inflating: train_data_0/00402_hr-0.png
#   inflating: train_data_0/00862_hr.dat
#   inflating: train_data_0/00020_hr.hea
#   inflating: train_data_0/00320_hr.hea
#   inflating: train_data_0/00868_hr-0.png
#   inflating: train_data_0/00505_hr-0.png
#   inflating: train_data_0/00488_hr-0.png
#   inflating: train_data_0/00396_hr.hea
#   inflating: train_data_0/00017_hr.dat
#   inflating: train_data_0/00253_hr.dat
#   inflating: train_data_0/00480_hr-0.png
#   inflating: train_data_0/00712_hr.dat
#   inflating: train_data_0/00708_hr.dat
#   inflating: train_data_0/00494_hr-0.png
#   inflating: train_data_0/00743_hr.hea
#   inflating: train_data_0/00351_hr.hea
#   inflating: train_data_0/00972_hr-0.png
#   inflating: train_data_0/00855_hr.hea
#   inflating: train_data_0/00111_hr.dat
#   inflating: train_data_0/00244_hr-0.png
#   inflating: train_data_0/00834_hr.hea
#   inflating: train_data_0/00742_hr.hea
#   inflating: train_data_0/00885_hr.dat
#   inflating: train_data_0/00926_hr.hea
#   inflating: train_data_0/00934_hr.dat
#   inflating: train_data_0/00028_hr.hea
#   inflating: train_data_0/00493_hr.dat
#   inflating: train_data_0/00727_hr.dat
#   inflating: train_data_0/00164_hr.dat
#   inflating: train_data_0/00749_hr.hea
#   inflating: train_data_0/00613_hr-0.png
#   inflating: train_data_0/00731_hr.dat
#   inflating: train_data_0/00702_hr-0.png
#   inflating: train_data_0/00801_hr.dat
#   inflating: train_data_0/00494_hr.hea
#   inflating: train_data_0/00793_hr.hea
#   inflating: train_data_0/00313_hr.dat
#   inflating: train_data_0/00252_hr.hea
#   inflating: train_data_0/00871_hr.hea
#   inflating: train_data_0/00482_hr-0.png
#   inflating: train_data_0/00882_hr-0.png
#   inflating: train_data_0/00998_hr.dat
#   inflating: train_data_0/00132_hr-0.png
#   inflating: train_data_0/00718_hr.dat
#   inflating: train_data_0/00388_hr.dat
#   inflating: train_data_0/00845_hr.dat
#   inflating: train_data_0/00079_hr.hea
#   inflating: train_data_0/00152_hr.dat
#   inflating: train_data_0/00899_hr.dat
#   inflating: train_data_0/00277_hr.dat
#   inflating: train_data_0/00236_hr-0.png
#   inflating: train_data_0/00286_hr-0.png
#   inflating: train_data_0/00543_hr-0.png
#   inflating: train_data_0/00312_hr.dat
#   inflating: train_data_0/00967_hr.dat
#   inflating: train_data_0/00928_hr-0.png
#   inflating: train_data_0/00615_hr.dat
#   inflating: train_data_0/00158_hr.dat
#   inflating: train_data_0/00966_hr.dat
#   inflating: train_data_0/00436_hr.hea
#   inflating: train_data_0/00329_hr.dat
#   inflating: train_data_0/00566_hr-0.png
#   inflating: train_data_0/00256_hr.dat
#   inflating: train_data_0/00016_hr-0.png
#   inflating: train_data_0/00571_hr-0.png
#   inflating: train_data_0/00495_hr.hea
#   inflating: train_data_0/00080_hr.hea
#   inflating: train_data_0/00024_hr-0.png
#   inflating: train_data_0/00931_hr-0.png
#   inflating: train_data_0/00673_hr.dat
#   inflating: train_data_0/00835_hr-0.png
#   inflating: train_data_0/00500_hr.dat
#   inflating: train_data_0/00606_hr.dat
#   inflating: train_data_0/00031_hr.dat
#   inflating: train_data_0/00090_hr-0.png
#   inflating: train_data_0/00867_hr.dat
#   inflating: train_data_0/00695_hr.dat
#   inflating: train_data_0/00669_hr-0.png
#   inflating: train_data_0/00399_hr.hea
#   inflating: train_data_0/00721_hr-0.png
#   inflating: train_data_0/00235_hr.hea
#   inflating: train_data_0/00812_hr.hea
#   inflating: train_data_0/00544_hr-0.png
#   inflating: train_data_0/00146_hr.hea
#   inflating: train_data_0/00919_hr.dat
#   inflating: train_data_0/00647_hr.hea
#   inflating: train_data_0/00619_hr.hea
#   inflating: train_data_0/00614_hr-0.png
#   inflating: train_data_0/00603_hr-0.png
#   inflating: train_data_0/00875_hr.hea
#   inflating: train_data_0/00593_hr.hea
#   inflating: train_data_0/00853_hr.dat
#   inflating: train_data_0/00892_hr-0.png
#   inflating: train_data_0/00341_hr.hea
#   inflating: train_data_0/00100_hr.hea
#   inflating: train_data_0/00055_hr.hea
#   inflating: train_data_0/00227_hr.hea
#   inflating: train_data_0/00402_hr.hea
#   inflating: train_data_0/00285_hr-0.png
#   inflating: train_data_0/00284_hr.dat
#   inflating: train_data_0/00423_hr.hea
#   inflating: train_data_0/00165_hr-0.png
#   inflating: train_data_0/00288_hr-0.png
#   inflating: train_data_0/00783_hr.dat
#   inflating: train_data_0/00754_hr.dat
#   inflating: train_data_0/00846_hr.dat
#   inflating: train_data_0/00608_hr-0.png
#   inflating: train_data_0/00309_hr.dat
#   inflating: train_data_0/00421_hr.hea
#   inflating: train_data_0/00627_hr-0.png
#   inflating: train_data_0/00634_hr-0.png
#   inflating: train_data_0/00176_hr.dat
#   inflating: train_data_0/00936_hr.dat
#   inflating: train_data_0/00374_hr-0.png
#   inflating: train_data_0/00611_hr-0.png
#   inflating: train_data_0/00300_hr.dat
#   inflating: train_data_0/00156_hr-0.png
#   inflating: train_data_0/00008_hr-0.png
#   inflating: train_data_0/00510_hr.hea
#   inflating: train_data_0/00806_hr.hea
#   inflating: train_data_0/00267_hr.hea
#   inflating: train_data_0/00086_hr-0.png
#   inflating: train_data_0/00788_hr.dat
#   inflating: train_data_0/00503_hr-0.png
#   inflating: train_data_0/00362_hr.hea
#   inflating: train_data_0/00255_hr.dat
#   inflating: train_data_0/00329_hr-0.png
#   inflating: train_data_0/00171_hr.dat
#   inflating: train_data_0/00926_hr-0.png
#   inflating: train_data_0/00650_hr.hea
#   inflating: train_data_0/00464_hr.hea
#   inflating: train_data_0/00098_hr.dat
#   inflating: train_data_0/00530_hr.dat
#   inflating: train_data_0/00115_hr-0.png
#   inflating: train_data_0/00041_hr.dat
#   inflating: train_data_0/00277_hr-0.png
#   inflating: train_data_0/00446_hr-0.png
#   inflating: train_data_0/00624_hr.hea
#   inflating: train_data_0/00182_hr.dat
#   inflating: train_data_0/00651_hr.dat
#   inflating: train_data_0/00759_hr.hea
#   inflating: train_data_0/00233_hr.dat
#   inflating: train_data_0/00714_hr-0.png
#   inflating: train_data_0/00255_hr-0.png
#   inflating: train_data_0/00679_hr.hea
#   inflating: train_data_0/00706_hr.dat
#   inflating: train_data_0/00335_hr.hea
#   inflating: train_data_0/00588_hr.hea
#   inflating: train_data_0/00592_hr.hea
#   inflating: train_data_0/00063_hr.hea
#   inflating: train_data_0/00444_hr.dat
#   inflating: train_data_0/00484_hr-0.png
#   inflating: train_data_0/00825_hr-0.png
#   inflating: train_data_0/00367_hr.dat
#   inflating: train_data_0/00948_hr-0.png
#   inflating: train_data_0/00397_hr-0.png
#   inflating: train_data_0/00983_hr.dat
#   inflating: train_data_0/00599_hr.dat
#   inflating: train_data_0/00903_hr.hea
#   inflating: train_data_0/00498_hr.dat
#   inflating: train_data_0/00914_hr.hea
#   inflating: train_data_0/00026_hr-0.png
#   inflating: train_data_0/00547_hr.hea
#   inflating: train_data_0/00631_hr.dat
#   inflating: train_data_0/00989_hr.dat
#   inflating: train_data_0/00569_hr.hea
#   inflating: train_data_0/00735_hr-0.png
#   inflating: train_data_0/00986_hr-0.png
#   inflating: train_data_0/00435_hr.hea
#   inflating: train_data_0/00791_hr.hea
#   inflating: train_data_0/00513_hr-0.png
#   inflating: train_data_0/00168_hr.hea
#   inflating: train_data_0/00556_hr-0.png
#   inflating: train_data_0/00936_hr-0.png
#   inflating: train_data_0/00786_hr.hea
#   inflating: train_data_0/00737_hr.hea
#   inflating: train_data_0/00974_hr.dat
#   inflating: train_data_0/00128_hr-0.png
#   inflating: train_data_0/00785_hr.hea
#   inflating: train_data_0/00109_hr-0.png
#   inflating: train_data_0/00402_hr.dat
#   inflating: train_data_0/00093_hr-0.png
#   inflating: train_data_0/00737_hr.dat
#   inflating: train_data_0/00929_hr.dat
#   inflating: train_data_0/00010_hr.dat
#   inflating: train_data_0/00756_hr.hea
#   inflating: train_data_0/00057_hr-0.png
#   inflating: train_data_0/00518_hr-0.png
#   inflating: train_data_0/00961_hr.dat
#   inflating: train_data_0/00147_hr-0.png
#   inflating: train_data_0/00783_hr-0.png
#   inflating: train_data_0/00662_hr-0.png
#   inflating: train_data_0/00103_hr-0.png
#   inflating: train_data_0/00589_hr.dat
#   inflating: train_data_0/00624_hr.dat
#   inflating: train_data_0/00162_hr-0.png
#   inflating: train_data_0/00129_hr-0.png
#   inflating: train_data_0/00348_hr.hea
#   inflating: train_data_0/00891_hr.hea
#   inflating: train_data_0/00186_hr.dat
#   inflating: train_data_0/00549_hr-0.png
#   inflating: train_data_0/00161_hr.hea
#   inflating: train_data_0/00283_hr.hea
#   inflating: train_data_0/00040_hr.hea
#   inflating: train_data_0/00877_hr-0.png
#   inflating: train_data_0/00982_hr.hea
#   inflating: train_data_0/00724_hr-0.png
#   inflating: train_data_0/00416_hr.dat
#   inflating: train_data_0/00561_hr-0.png
#   inflating: train_data_0/00177_hr-0.png
#   inflating: train_data_0/00759_hr-0.png
#   inflating: train_data_0/00157_hr-0.png
#   inflating: train_data_0/00690_hr.hea
#   inflating: train_data_0/00332_hr.dat
#   inflating: train_data_0/00073_hr-0.png
#   inflating: train_data_0/00887_hr.dat
#   inflating: train_data_0/00400_hr.hea
#   inflating: train_data_0/00334_hr.hea
#   inflating: train_data_0/00122_hr.hea
#   inflating: train_data_0/00504_hr.hea
#   inflating: train_data_0/00985_hr.dat
#   inflating: train_data_0/00743_hr.dat
#   inflating: train_data_0/00482_hr.hea
#   inflating: train_data_0/00997_hr.dat
#   inflating: train_data_0/00093_hr.dat
#   inflating: train_data_0/00319_hr-0.png
#   inflating: train_data_0/00658_hr.hea
#   inflating: train_data_0/00653_hr-0.png
#   inflating: train_data_0/00632_hr.dat
#   inflating: train_data_0/00860_hr-0.png
#   inflating: train_data_0/00765_hr.dat
#   inflating: train_data_0/00745_hr-0.png
#   inflating: train_data_0/00005_hr.hea
#   inflating: train_data_0/00810_hr-0.png
#   inflating: train_data_0/00832_hr.hea
#   inflating: train_data_0/00357_hr.dat
#   inflating: train_data_0/00178_hr.hea
#   inflating: train_data_0/00960_hr.dat
#   inflating: train_data_0/00070_hr.hea
#   inflating: train_data_0/00639_hr.dat
#   inflating: train_data_0/00345_hr.hea
#   inflating: train_data_0/00570_hr.dat
#   inflating: train_data_0/00965_hr-0.png
#   inflating: train_data_0/00183_hr-0.png
#   inflating: train_data_0/00531_hr.dat
#   inflating: train_data_0/00808_hr.hea
#   inflating: train_data_0/00078_hr.dat
#   inflating: train_data_0/00269_hr-0.png
#   inflating: train_data_0/00591_hr.dat
#   inflating: train_data_0/00711_hr.hea
#   inflating: train_data_0/00999_hr-0.png
#   inflating: train_data_0/00659_hr.hea
#   inflating: train_data_0/00574_hr-0.png
#   inflating: train_data_0/00662_hr.hea
#   inflating: train_data_0/00509_hr.hea
#   inflating: train_data_0/00352_hr.dat
#   inflating: train_data_0/00082_hr.hea
#   inflating: train_data_0/00100_hr.dat
#   inflating: train_data_0/00579_hr.dat
#   inflating: train_data_0/00361_hr.hea
#   inflating: train_data_0/00195_hr-0.png
#   inflating: train_data_0/00153_hr.hea
#   inflating: train_data_0/00780_hr.hea
#   inflating: train_data_0/00913_hr.dat
#   inflating: train_data_0/00217_hr-0.png
#   inflating: train_data_0/00785_hr-0.png
#   inflating: train_data_0/00624_hr-0.png
#   inflating: train_data_0/00201_hr-0.png
#   inflating: train_data_0/00229_hr.dat
#   inflating: train_data_0/00578_hr.dat
#   inflating: train_data_0/00845_hr.hea
#   inflating: train_data_0/00336_hr-0.png
#   inflating: train_data_0/00496_hr-0.png
#   inflating: train_data_0/00644_hr.dat
#   inflating: train_data_0/00493_hr.hea
#   inflating: train_data_0/00094_hr-0.png
#   inflating: train_data_0/00266_hr.dat
#   inflating: train_data_0/00581_hr-0.png
#   inflating: train_data_0/00554_hr.hea
#   inflating: train_data_0/00994_hr.hea
#   inflating: train_data_0/00605_hr-0.png
#   inflating: train_data_0/00533_hr.hea
#   inflating: train_data_0/00378_hr-0.png
#   inflating: train_data_0/00647_hr-0.png
#   inflating: train_data_0/00360_hr.dat
#   inflating: train_data_0/00399_hr-0.png
#   inflating: train_data_0/00131_hr.hea
#   inflating: train_data_0/00746_hr-0.png
#   inflating: train_data_0/00602_hr.dat
#   inflating: train_data_0/00423_hr.dat
#   inflating: train_data_0/00064_hr.dat
#   inflating: train_data_0/00267_hr.dat
#   inflating: train_data_0/00925_hr.hea
#   inflating: train_data_0/00744_hr.hea
#   inflating: train_data_0/00940_hr-0.png
#   inflating: train_data_0/00629_hr.dat
#   inflating: train_data_0/00188_hr.hea
#   inflating: train_data_0/00384_hr.dat
#   inflating: train_data_0/00818_hr-0.png
#   inflating: train_data_0/00927_hr.hea
#   inflating: train_data_0/00418_hr.dat
#   inflating: train_data_0/00792_hr-0.png
#   inflating: train_data_0/00193_hr-0.png
#   inflating: train_data_0/00924_hr-0.png
#   inflating: train_data_0/00785_hr.dat
#   inflating: train_data_0/00044_hr-0.png
#   inflating: train_data_0/00371_hr-0.png
#   inflating: train_data_0/00168_hr.dat
#   inflating: train_data_0/00362_hr-0.png
#   inflating: train_data_0/00101_hr.dat
#   inflating: train_data_0/00252_hr-0.png
#   inflating: train_data_0/00824_hr-0.png
#   inflating: train_data_0/00397_hr.hea
#   inflating: train_data_0/00276_hr-0.png
#   inflating: train_data_0/00673_hr.hea
#   inflating: train_data_0/00643_hr.dat
#   inflating: train_data_0/00322_hr.dat
#   inflating: train_data_0/00325_hr.dat
#   inflating: train_data_0/00917_hr.hea
#   inflating: train_data_0/00622_hr.dat
#   inflating: train_data_0/00170_hr.dat
#   inflating: train_data_0/00862_hr-0.png
#   inflating: train_data_0/00688_hr.hea
#   inflating: train_data_0/00995_hr.hea
#   inflating: train_data_0/00805_hr.dat
#   inflating: train_data_0/00024_hr.dat
#   inflating: train_data_0/00368_hr.hea
#   inflating: train_data_0/00349_hr.hea
#   inflating: train_data_0/00334_hr.dat
#   inflating: train_data_0/00339_hr-0.png
#   inflating: train_data_0/00999_hr.hea
#   inflating: train_data_0/00025_hr.dat
#   inflating: train_data_0/00347_hr-0.png
#   inflating: train_data_0/00723_hr.dat
#   inflating: train_data_0/00781_hr.dat
#   inflating: train_data_0/00231_hr.dat
#   inflating: train_data_0/00387_hr-0.png
#   inflating: train_data_0/00657_hr-0.png
#   inflating: train_data_0/00740_hr.dat
#   inflating: train_data_0/00467_hr.dat
#   inflating: train_data_0/00262_hr.hea
#   inflating: train_data_0/00561_hr.hea
#   inflating: train_data_0/00835_hr.dat
#   inflating: train_data_0/00522_hr.hea
#   inflating: train_data_0/00087_hr.dat
#   inflating: train_data_0/00194_hr-0.png
#   inflating: train_data_0/00045_hr.hea
#   inflating: train_data_0/00825_hr.dat
#   inflating: train_data_0/00021_hr-0.png
#   inflating: train_data_0/00732_hr-0.png
#   inflating: train_data_0/00726_hr.hea
#   inflating: train_data_0/00396_hr.dat
#   inflating: train_data_0/00487_hr.hea
#   inflating: train_data_0/00927_hr-0.png
#   inflating: train_data_0/00447_hr-0.png
#   inflating: train_data_0/00507_hr.dat
#   inflating: train_data_0/00022_hr.dat
#   inflating: train_data_0/00070_hr-0.png
#   inflating: train_data_0/00502_hr-0.png
#   inflating: train_data_0/00536_hr.dat
#   inflating: train_data_0/00126_hr-0.png
#   inflating: train_data_0/00889_hr-0.png
#   inflating: train_data_0/00360_hr.hea
#   inflating: train_data_0/00649_hr-0.png
#   inflating: train_data_0/00068_hr.hea
#   inflating: train_data_0/00229_hr-0.png
#   inflating: train_data_0/00092_hr-0.png
#   inflating: train_data_0/00587_hr.dat
#   inflating: train_data_0/00923_hr-0.png
#   inflating: train_data_0/00053_hr.hea
#   inflating: train_data_0/00050_hr.dat
#   inflating: train_data_0/00078_hr.hea
#   inflating: train_data_0/00148_hr.dat
#   inflating: train_data_0/00658_hr-0.png
#   inflating: train_data_0/00931_hr.dat
#   inflating: train_data_0/00015_hr.hea
#   inflating: train_data_0/00039_hr.dat
#   inflating: train_data_0/00903_hr-0.png
#   inflating: train_data_0/00874_hr.hea
#   inflating: train_data_0/00907_hr.hea
#   inflating: train_data_0/00377_hr-0.png
#   inflating: train_data_0/00032_hr.dat
#   inflating: train_data_0/00117_hr.dat
#   inflating: train_data_0/00256_hr-0.png
#   inflating: train_data_0/00321_hr.hea
#   inflating: train_data_0/00691_hr.dat
# ...
#   inflating: train_data_0/00049_hr.hea
#   inflating: train_data_0/00066_hr-0.png
#   inflating: train_data_0/00959_hr.dat
#   inflating: train_data_0/00101_hr-0.png
#   inflating: train_data_0/00976_hr-0.png
#   inflating: train_data_0/00800_hr.hea
#   inflating: train_data_0/00042_hr-0.png
#   inflating: train_data_0/00449_hr-0.png
#   inflating: train_data_0/00388_hr-0.png
#   inflating: train_data_0/00825_hr.hea
#   inflating: train_data_0/00417_hr.dat
#   inflating: train_data_0/00489_hr.dat
#   inflating: train_data_0/00118_hr-0.png
#   inflating: train_data_0/00240_hr.dat
#   inflating: train_data_0/00732_hr.hea
#   inflating: train_data_0/00344_hr.dat
#   inflating: train_data_0/00726_hr-0.png
#   inflating: train_data_0/00529_hr-0.png
#   inflating: train_data_0/00449_hr.dat
#   inflating: train_data_0/00499_hr.hea
#   inflating: train_data_0/00607_hr.dat
#   inflating: train_data_0/00931_hr.hea
#   inflating: train_data_0/00990_hr.dat
#   inflating: train_data_0/00768_hr.dat
#   inflating: train_data_0/00650_hr-0.png
#   inflating: train_data_0/00415_hr-0.png
#   inflating: train_data_0/00051_hr.hea
#   inflating: train_data_0/00795_hr-0.png
#   inflating: train_data_0/00956_hr-0.png
#   inflating: train_data_0/00569_hr.dat
#   inflating: train_data_0/00210_hr-0.png
#   inflating: train_data_0/00149_hr-0.png
#   inflating: train_data_0/00419_hr.dat
#   inflating: train_data_0/00024_hr.hea
#   inflating: train_data_0/00991_hr.hea
#   inflating: train_data_0/00760_hr.hea
#   inflating: train_data_0/00992_hr.hea
#   inflating: train_data_0/00921_hr-0.png
#   inflating: train_data_0/00057_hr.dat
#   inflating: train_data_0/00550_hr.hea
#   inflating: train_data_0/00463_hr.dat
#   inflating: train_data_0/00180_hr-0.png
#   inflating: train_data_0/00322_hr.hea
#   inflating: train_data_0/00078_hr-0.png
#   inflating: train_data_0/00769_hr-0.png
#   inflating: train_data_0/00228_hr.dat
#   inflating: train_data_0/00269_hr.hea
#   inflating: train_data_0/00542_hr-0.png
#   inflating: train_data_0/00195_hr.dat
#   inflating: train_data_0/00578_hr-0.png
#   inflating: train_data_0/00307_hr-0.png
#   inflating: train_data_0/00485_hr-0.png
#   inflating: train_data_0/00731_hr.hea
#   inflating: train_data_0/00766_hr-0.png
#   inflating: train_data_0/00619_hr-0.png
#   inflating: train_data_0/00316_hr.hea
#   inflating: train_data_0/00781_hr.hea
#   inflating: train_data_0/00116_hr-0.png
#   inflating: train_data_0/00271_hr.hea
#   inflating: train_data_0/00007_hr.hea
#   inflating: train_data_0/00906_hr-0.png
#   inflating: train_data_0/00629_hr.hea
#   inflating: train_data_0/00843_hr-0.png
#   inflating: train_data_0/00209_hr.hea
#   inflating: train_data_0/00449_hr.hea
#   inflating: train_data_0/00413_hr.hea
#   inflating: train_data_0/00973_hr.dat
#   inflating: train_data_0/00756_hr-0.png
#   inflating: train_data_0/00992_hr.dat
#   inflating: train_data_0/00160_hr-0.png
#   inflating: train_data_0/00894_hr.dat
#   inflating: train_data_0/00833_hr.hea
#   inflating: train_data_0/00392_hr-0.png
#   inflating: train_data_0/00913_hr-0.png
#   inflating: train_data_0/00353_hr.dat
#   inflating: train_data_0/00776_hr-0.png
#   inflating: train_data_0/00607_hr.hea
#   inflating: train_data_0/00701_hr-0.png
#   inflating: train_data_0/00320_hr-0.png
#   inflating: train_data_0/00963_hr.dat
#   inflating: train_data_0/00631_hr-0.png
#   inflating: train_data_0/00242_hr-0.png
#   inflating: train_data_0/00439_hr-0.png
#   inflating: train_data_0/00799_hr.hea
#   inflating: train_data_0/00310_hr.dat
#   inflating: train_data_0/00212_hr.hea
#   inflating: train_data_0/00472_hr.dat
#   inflating: train_data_0/00960_hr.hea
#   inflating: train_data_0/00752_hr.dat
#   inflating: train_data_0/00882_hr.dat
#   inflating: train_data_0/00979_hr-0.png
#   inflating: train_data_0/00411_hr-0.png
#   inflating: train_data_0/00794_hr.dat
#   inflating: train_data_0/00291_hr.dat
#   inflating: train_data_0/00279_hr-0.png
#   inflating: train_data_0/00114_hr.dat
#   inflating: train_data_0/00513_hr.dat
#   inflating: train_data_0/00886_hr.dat
#   inflating: train_data_0/00817_hr-0.png
#   inflating: train_data_0/00232_hr.hea
#   inflating: train_data_0/00717_hr.hea
#   inflating: train_data_0/00501_hr.dat
#   inflating: train_data_0/00626_hr.hea
#   inflating: train_data_0/00823_hr-0.png
#   inflating: train_data_0/00138_hr.dat
#   inflating: train_data_0/00927_hr.dat
#   inflating: train_data_0/00767_hr.dat
#   inflating: train_data_0/00822_hr-0.png
#   inflating: train_data_0/00011_hr.hea
#   inflating: train_data_0/00859_hr.hea
#   inflating: train_data_0/00506_hr.hea
#   inflating: train_data_0/00971_hr.hea
#   inflating: train_data_0/00607_hr-0.png
#   inflating: train_data_0/00734_hr.hea
#   inflating: train_data_0/00729_hr.dat
#   inflating: train_data_0/00382_hr.dat
#   inflating: train_data_0/00103_hr.dat
#   inflating: train_data_0/00171_hr-0.png
#   inflating: train_data_0/00208_hr.hea
#   inflating: train_data_0/00540_hr.dat
#   inflating: train_data_0/00864_hr.hea
#   inflating: train_data_0/00753_hr.hea
#   inflating: train_data_0/00630_hr-0.png
#   inflating: train_data_0/00817_hr.dat
#   inflating: train_data_0/00378_hr.dat
#   inflating: train_data_0/00768_hr.hea
#   inflating: train_data_0/00572_hr-0.png
#   inflating: train_data_0/00314_hr.hea
#   inflating: train_data_0/00031_hr.hea
#   inflating: train_data_0/00127_hr-0.png
#   inflating: train_data_0/00455_hr.dat
#   inflating: train_data_0/00921_hr.dat
#   inflating: train_data_0/00594_hr-0.png
#   inflating: train_data_0/00802_hr.hea
#   inflating: train_data_0/00903_hr.dat
#   inflating: train_data_0/00380_hr.dat
#   inflating: train_data_0/00929_hr.hea
#   inflating: train_data_0/00584_hr.hea
#   inflating: train_data_0/00760_hr.dat
#   inflating: train_data_0/00120_hr-0.png
#   inflating: train_data_0/00781_hr-0.png
#   inflating: train_data_0/00220_hr-0.png
#   inflating: train_data_0/00635_hr.dat
#   inflating: train_data_0/00286_hr.hea
#   inflating: train_data_0/00501_hr.hea
#   inflating: train_data_0/00774_hr.hea
#   inflating: train_data_0/00976_hr.hea
#   inflating: train_data_0/00051_hr.dat
#   inflating: train_data_0/00504_hr-0.png
#   inflating: train_data_0/00144_hr.dat
#   inflating: train_data_0/00942_hr.hea
#   inflating: train_data_0/00879_hr.dat
#   inflating: train_data_0/00067_hr-0.png
#   inflating: train_data_0/00957_hr.dat
#   inflating: train_data_0/00027_hr-0.png
#   inflating: train_data_0/00995_hr.dat
#   inflating: train_data_0/00533_hr.dat
#   inflating: train_data_0/00509_hr.dat
#   inflating: train_data_0/00394_hr-0.png
#   inflating: train_data_0/00937_hr.hea
#   inflating: train_data_0/00743_hr-0.png
#   inflating: train_data_0/00510_hr.dat
#   inflating: train_data_0/00686_hr-0.png
#   inflating: train_data_0/00242_hr.dat
#   inflating: train_data_0/00660_hr.dat
#   inflating: train_data_0/00775_hr-0.png
#   inflating: train_data_0/00046_hr.hea
#   inflating: train_data_0/00492_hr.hea
#   inflating: train_data_0/00427_hr-0.png
#   inflating: train_data_0/00912_hr.hea
#   inflating: train_data_0/00305_hr-0.png
#   inflating: train_data_0/00190_hr-0.png
#   inflating: train_data_0/00407_hr-0.png
#   inflating: train_data_0/00710_hr.hea
#   inflating: train_data_0/00805_hr.hea
#   inflating: train_data_0/00641_hr-0.png
#   inflating: train_data_0/00010_hr.hea
#   inflating: train_data_0/00289_hr-0.png
#   inflating: train_data_0/00247_hr.hea
#   inflating: train_data_0/00981_hr.hea
#   inflating: train_data_0/00883_hr.dat
#   inflating: train_data_0/00598_hr.dat
#   inflating: train_data_0/00338_hr-0.png
#   inflating: train_data_0/00148_hr.hea
#   inflating: train_data_0/00672_hr.hea
#   inflating: train_data_0/00865_hr-0.png
#   inflating: train_data_0/00762_hr.dat
#   inflating: train_data_0/00953_hr-0.png
#   inflating: train_data_0/00628_hr.dat
#   inflating: train_data_0/00862_hr.hea
#   inflating: train_data_0/00970_hr-0.png
#   inflating: train_data_0/00853_hr-0.png
#   inflating: train_data_0/00052_hr.hea
#   inflating: train_data_0/00534_hr.hea
#   inflating: train_data_0/00028_hr.dat
#   inflating: train_data_0/00002_hr.dat
#   inflating: train_data_0/00484_hr.hea
#   inflating: train_data_0/00601_hr-0.png
#   inflating: train_data_0/00365_hr.hea
#   inflating: train_data_0/00653_hr.dat
#   inflating: train_data_0/00179_hr.dat
#   inflating: train_data_0/00354_hr-0.png
#   inflating: train_data_0/00061_hr.dat
#   inflating: train_data_0/00917_hr-0.png
#   inflating: train_data_0/00635_hr.hea
#   inflating: train_data_0/00672_hr-0.png
#   inflating: train_data_0/00096_hr-0.png
#   inflating: train_data_0/00529_hr.dat
#   inflating: train_data_0/00189_hr.dat
#   inflating: train_data_0/00427_hr.hea
#   inflating: train_data_0/00412_hr.hea
#   inflating: train_data_0/00555_hr.hea
#   inflating: train_data_0/00480_hr.hea
#   inflating: train_data_0/00803_hr-0.png
#   inflating: train_data_0/00298_hr.hea
#   inflating: train_data_0/00444_hr.hea
#   inflating: train_data_0/00714_hr.dat
#   inflating: train_data_0/00690_hr.dat
#   inflating: train_data_0/00446_hr.hea
#   inflating: train_data_0/00273_hr.hea
#   inflating: train_data_0/00844_hr-0.png
#   inflating: train_data_0/00567_hr.dat
#   inflating: train_data_0/00947_hr-0.png
#   inflating: train_data_0/00880_hr-0.png
#   inflating: train_data_0/00493_hr-0.png
#   inflating: train_data_0/00374_hr.hea
#   inflating: train_data_0/00286_hr.dat
#   inflating: train_data_0/00426_hr-0.png
#   inflating: train_data_0/00946_hr.dat
#   inflating: train_data_0/00546_hr.dat
#   inflating: train_data_0/00516_hr-0.png
#   inflating: train_data_0/00911_hr.hea
#   inflating: train_data_0/00998_hr-0.png
#   inflating: train_data_0/00763_hr.hea
#   inflating: train_data_0/00064_hr.hea
#   inflating: train_data_0/00725_hr.hea
#   inflating: train_data_0/00625_hr-0.png
#   inflating: train_data_0/00443_hr.dat
#   inflating: train_data_0/00991_hr-0.png
#   inflating: train_data_0/00583_hr.hea
#   inflating: train_data_0/00241_hr.dat
#   inflating: train_data_0/00655_hr-0.png
#   inflating: train_data_0/00613_hr.dat
#   inflating: train_data_0/00842_hr.hea
#   inflating: train_data_0/00897_hr-0.png
#   inflating: train_data_0/00507_hr.hea
#   inflating: train_data_0/00266_hr-0.png
#   inflating: train_data_0/00230_hr-0.png
#   inflating: train_data_0/00106_hr-0.png
#   inflating: train_data_0/00733_hr.dat
#   inflating: train_data_0/00221_hr.dat
#   inflating: train_data_0/00428_hr.hea
#   inflating: train_data_0/00082_hr-0.png
#   inflating: train_data_0/00842_hr-0.png
#   inflating: train_data_0/00588_hr.dat
#   inflating: train_data_0/00338_hr.hea
#   inflating: train_data_0/00613_hr.hea
#   inflating: train_data_0/00407_hr.hea
#   inflating: train_data_0/00475_hr-0.png
#   inflating: train_data_0/00766_hr.dat
#   inflating: train_data_0/00249_hr.dat
#   inflating: train_data_0/00224_hr.dat
#   inflating: train_data_0/00908_hr.dat
#   inflating: train_data_0/00434_hr-0.png
#   inflating: train_data_0/00767_hr-0.png
#   inflating: train_data_0/00188_hr.dat
#   inflating: train_data_0/00114_hr.hea
#   inflating: train_data_0/00756_hr.dat
#   inflating: train_data_0/00270_hr.dat
#   inflating: train_data_0/00298_hr-0.png
#   inflating: train_data_0/00448_hr-0.png
#   inflating: train_data_0/00950_hr.dat
#   inflating: train_data_0/00871_hr-0.png
#   inflating: train_data_0/00022_hr.hea
#   inflating: train_data_0/00290_hr.dat
#   inflating: train_data_0/00105_hr-0.png
#   inflating: train_data_0/00702_hr.hea
#   inflating: train_data_0/00527_hr.dat
#   inflating: train_data_0/00846_hr-0.png
#   inflating: train_data_0/00521_hr-0.png
#   inflating: train_data_0/00073_hr.dat
#   inflating: train_data_0/00112_hr.dat
#   inflating: train_data_0/00039_hr-0.png
#   inflating: train_data_0/00020_hr-0.png
#   inflating: train_data_0/00196_hr.dat
#   inflating: train_data_0/00891_hr-0.png
#   inflating: train_data_0/00430_hr.dat
#   inflating: train_data_0/00792_hr.dat
#   inflating: train_data_0/00439_hr.dat
#   inflating: train_data_0/00890_hr.hea
#   inflating: train_data_0/00687_hr-0.png
#   inflating: train_data_0/00787_hr-0.png
#   inflating: train_data_0/00629_hr-0.png
#   inflating: train_data_0/00366_hr-0.png
#   inflating: train_data_0/00095_hr.hea
#   inflating: train_data_0/00771_hr-0.png
#   inflating: train_data_0/00546_hr.hea
#   inflating: train_data_0/00818_hr.hea
#   inflating: train_data_0/00134_hr.dat
#   inflating: train_data_0/00509_hr-0.png
#   inflating: train_data_0/00063_hr.dat
#   inflating: train_data_0/00129_hr.hea
#   inflating: train_data_0/00644_hr-0.png
#   inflating: train_data_0/00342_hr.dat
#   inflating: train_data_0/00625_hr.hea
#   inflating: train_data_0/00634_hr.dat
#   inflating: train_data_0/00220_hr.hea
#   inflating: train_data_0/00226_hr-0.png
#   inflating: train_data_0/00349_hr-0.png
#   inflating: train_data_0/00866_hr-0.png
#   inflating: train_data_0/00289_hr.dat
#   inflating: train_data_0/00899_hr-0.png
#   inflating: train_data_0/00390_hr.hea
#   inflating: train_data_0/00292_hr.hea
#   inflating: train_data_0/00299_hr.dat
#   inflating: train_data_0/00460_hr-0.png
#   inflating: train_data_0/00033_hr.dat
#   inflating: train_data_0/00002_hr-0.png
#   inflating: train_data_0/00027_hr.hea
#   inflating: train_data_0/00664_hr.dat
#   inflating: train_data_0/00508_hr.hea
#   inflating: train_data_0/00307_hr.hea
#   inflating: train_data_0/00477_hr.dat
#   inflating: train_data_0/00764_hr.hea
#   inflating: train_data_0/00884_hr-0.png
#   inflating: train_data_0/00321_hr.dat
#   inflating: train_data_0/00538_hr-0.png
#   inflating: train_data_0/00162_hr.hea
#   inflating: train_data_0/00384_hr-0.png
#   inflating: train_data_0/00707_hr.dat
#   inflating: train_data_0/00811_hr.dat
#   inflating: train_data_0/00583_hr-0.png
#   inflating: train_data_0/00465_hr-0.png
#   inflating: train_data_0/00728_hr.hea
#   inflating: train_data_0/00596_hr.hea
#   inflating: train_data_0/00987_hr.dat
#   inflating: train_data_0/00576_hr-0.png
#   inflating: train_data_0/00451_hr.dat
#   inflating: train_data_0/00018_hr.dat
#   inflating: train_data_0/00294_hr.dat
#   inflating: train_data_0/00119_hr.hea
#   inflating: train_data_0/00156_hr.dat
#   inflating: train_data_0/00656_hr.dat
#   inflating: train_data_0/00002_hr.hea
#   inflating: train_data_0/00518_hr.hea
#   inflating: train_data_0/00860_hr.dat
#   inflating: train_data_0/00746_hr.hea
#   inflating: train_data_0/00565_hr-0.png
#   inflating: train_data_0/00237_hr.hea
#   inflating: train_data_0/00445_hr-0.png
#   inflating: train_data_0/00898_hr.hea
#   inflating: train_data_0/00240_hr-0.png
#   inflating: train_data_0/00585_hr.hea
#   inflating: train_data_0/00069_hr-0.png
#   inflating: train_data_0/00574_hr.hea
#   inflating: train_data_0/00552_hr.dat
#   inflating: train_data_0/00912_hr-0.png
#   inflating: train_data_0/00886_hr-0.png
#   inflating: train_data_0/00831_hr.hea
#   inflating: train_data_0/00900_hr.hea
#   inflating: train_data_0/00698_hr.hea
#   inflating: train_data_0/00090_hr.hea
#   inflating: train_data_0/00496_hr.dat
#   inflating: train_data_0/00599_hr-0.png
#   inflating: train_data_0/00541_hr.hea
#   inflating: train_data_0/00398_hr.hea
#   inflating: train_data_0/00534_hr-0.png
#   inflating: train_data_0/00579_hr.hea
#   inflating: train_data_0/00104_hr.hea
#   inflating: train_data_0/00122_hr-0.png
#   inflating: train_data_0/00061_hr-0.png
#   inflating: train_data_0/00811_hr.hea
#   inflating: train_data_0/00966_hr.hea
#   inflating: train_data_0/00068_hr.dat
#   inflating: train_data_0/00330_hr.hea
#   inflating: train_data_0/00524_hr.dat
#   inflating: train_data_0/00455_hr-0.png
#   inflating: train_data_0/00657_hr.dat
#   inflating: train_data_0/00716_hr.hea
#   inflating: train_data_0/00969_hr.hea
#   inflating: train_data_0/00088_hr.hea
#   inflating: train_data_0/00499_hr-0.png
#   inflating: train_data_0/00151_hr-0.png

# %% [markdown]
# ---
# # Original code by competition organisers
# ---

# %% [markdown]
# ---
# ### helper_code.py
# ---

# %%
#!/usr/bin/env python

# Do *not* edit this script.
# These are helper functions that you can use with your code.
# Check the example code to see how to use these functions in your code.

import numpy as np
import os
import sys
import wfdb

### Challenge variables
substring_labels = '# Labels:'
substring_images = '# Image:'

### Challenge data I/O functions

# Find the records in a folder and its subfolders.
def find_records(folder):
    records = set()
    for root, directories, files in os.walk(folder):
        for file in files:
            extension = os.path.splitext(file)[1]
            if extension == '.hea':
                record = os.path.relpath(os.path.join(root, file), folder)[:-4]
                records.add(record)
    records = sorted(records)
    return records

# Load the header for a record.
def load_header(record):
    header_file = get_header_file(record)
    header = load_text(header_file)
    return header

# Load the signals for a record.
def load_signals(record):
    signal_files = get_signal_files(record)
    path = os.path.split(record)[0]
    signal_files_exist = all(os.path.isfile(os.path.join(path, signal_file)) for signal_file in signal_files)
    if signal_files and signal_files_exist:
        signal, fields = wfdb.rdsamp(record)
    else:
        signal, fields = None, None
    return signal, fields

# Load the images for a record.
def load_images(record):
    from PIL import Image

    path = os.path.split(record)[0]
    image_files = get_image_files(record)

    images = list()
    for image_file in image_files:
        image_file_path = os.path.join(path, image_file)
        if os.path.isfile(image_file_path):
            image = Image.open(image_file_path)
            images.append(image)

    return images

# Load the labels for a record.
def load_labels(record):
    header = load_header(record)
    labels = get_labels_from_header(header)
    return labels

# Save the header for a record.
def save_header(record, header):
    header_file = get_header_file(record)
    save_text(header_file, header)

# Save the signals for a record.
def save_signals(record, signal, comments=list()):
    header = load_header(record)
    path, record = os.path.split(record)
    sampling_frequency = get_sampling_frequency(header)
    signal_formats = get_signal_formats(header)
    adc_gains = get_adc_gains(header)
    baselines = get_baselines(header)
    signal_units = get_signal_units(header)
    signal_names = get_signal_names(header)
    comments = [comment.replace('#', '').strip() for comment in comments]

    wfdb.wrsamp(record, fs=sampling_frequency, units=signal_units, sig_name=signal_names, \
                p_signal=signal, fmt=signal_formats, adc_gain=adc_gains, baseline=baselines, comments=comments,
                write_dir=path)

# Save the labels for a record.
def save_labels(record, labels):
    header_file = get_header_file(record)
    header = load_text(header_file)
    header += substring_labels + ' ' + ', '.join(labels) + '\n'
    save_text(header_file, header)
    return header

### Helper Challenge functions

# Load a text file as a string.
def load_text(filename):
    with open(filename, 'r') as f:
        string = f.read()
    return string

# Save a string as a text file.
def save_text(filename, string):
    with open(filename, 'w') as f:
        f.write(string)

# Get a variable from a string.
def get_variable(string, variable_name):
    variable = ''
    has_variable = False
    for l in string.split('\n'):
        if l.startswith(variable_name):
            variable = l[len(variable_name):].strip()
            has_variable = True
    return variable, has_variable

# Get variables from a string.
def get_variables(string, variable_name, sep=','):
    variables = list()
    has_variable = False
    for l in string.split('\n'):
        if l.startswith(variable_name):
            variables += [variable.strip() for variable in l[len(variable_name):].strip().split(sep)]
            has_variable = True
    return variables, has_variable

# Get the signal files from a header or a similar string.
def get_signal_files_from_header(string):
    signal_files = list()
    for i, l in enumerate(string.split('\n')):
        arrs = [arr.strip() for arr in l.split(' ')]
        if i==0 and not l.startswith('#'):
            num_channels = int(arrs[1])
        elif i<=num_channels and not l.startswith('#'):
            signal_file = arrs[0]
            if signal_file not in signal_files:
                signal_files.append(signal_file)
        else:
            break
    return signal_files

# Get the image files from a header or a similar string.
def get_image_files_from_header(string):
    images, has_image = get_variables(string, substring_images)
    if not has_image:
        raise Exception('No images available: did you forget to generate or include the images?')
    return images

# Get the labels from a header or a similar string.
def get_labels_from_header(string):
    labels, has_labels = get_variables(string, substring_labels)
    if not has_labels:
        raise Exception('No labels available: are you trying to load the labels from the held-out data, or did you forget to prepare the data to include the labels?')
    return labels

# Get the header file for a record.
def get_header_file(record):
    if not record.endswith('.hea'):
        header_file = record + '.hea'
    else:
        header_file = record
    return header_file

# Get the signal files for a record.
def get_signal_files(record):
    header_file = get_header_file(record)
    header = load_text(header_file)
    signal_files = get_signal_files_from_header(header)
    return signal_files

# Get the image files for a record.
def get_image_files(record):
    header_file = get_header_file(record)
    header = load_text(header_file)
    image_files = get_image_files_from_header(header)
    return image_files

### WFDB functions

# Get the record name from a header file.
def get_record_name(string):
    value = string.split('\n')[0].split(' ')[0].split('/')[0].strip()
    return value

# Get the number of signals from a header file.
def get_num_signals(string):
    value = string.split('\n')[0].split(' ')[1].strip()
    if is_integer(value):
        value = int(value)
    else:
        value = None
    return value

# Get the sampling frequency from a header file.
def get_sampling_frequency(string):
    value = string.split('\n')[0].split(' ')[2].split('/')[0].strip()
    if is_number(value):
        value = float(value)
    else:
        value = None
    return value

# Get the number of samples from a header file.
def get_num_samples(string):
    value = string.split('\n')[0].split(' ')[3].strip()
    if is_integer(value):
        value = int(value)
    else:
        value = None
    return value

# Get the signal formats from a header file.
def get_signal_formats(string):
    num_signals = get_num_signals(string)
    values = list()
    for i, l in enumerate(string.split('\n')):
        if 1 <= i <= num_signals:
            field = l.split(' ')[1]
            if 'x' in field:
                field = field.split('x')[0]
            if ':' in field:
                field = field.split(':')[0]
            if '+' in field:
                field = field.split('+')[0]
            value = field
            values.append(value)
    return values

# Get the ADC gains from a header file.
def get_adc_gains(string):
    num_signals = get_num_signals(string)
    values = list()
    for i, l in enumerate(string.split('\n')):
        if 1 <= i <= num_signals:
            field = l.split(' ')[2]
            if '/' in field:
                field = field.split('/')[0]
            if '(' in field and ')' in field:
                field = field.split('(')[0]
            value = float(field)
            values.append(value)
    return values

# Get the baselines from a header file.
def get_baselines(string):
    num_signals = get_num_signals(string)
    values = list()
    for i, l in enumerate(string.split('\n')):
        if 1 <= i <= num_signals:
            field = l.split(' ')[2]
            if '/' in field:
                field = field.split('/')[0]
            if '(' in field and ')' in field:
                field = field.split('(')[1].split(')')[0]
            else:
                field = get_adc_zeros(string)[i-1]
            value = int(field)
            values.append(value)
    return values

# Get the signal units from a header file.
def get_signal_units(string):
    num_signals = get_num_signals(string)
    values = list()
    for i, l in enumerate(string.split('\n')):
        if 1 <= i <= num_signals:
            field = l.split(' ')[2]
            if '/' in field:
                value = field.split('/')[1]
            else:
                value = 'mV'
            values.append(value)
    return values

# Get the ADC resolutions from a header file.
def get_adc_resolutions(string):
    num_signals = get_num_signals(string)
    values = list()
    for i, l in enumerate(string.split('\n')):
        if 1 <= i <= num_signals:
            field = l.split(' ')[3]
            value = int(field)
            values.append(value)
    return values

# Get the ADC zeros from a header file.
def get_adc_zeros(string):
    num_signals = get_num_signals(string)
    values = list()
    for i, l in enumerate(string.split('\n')):
        if 1 <= i <= num_signals:
            field = l.split(' ')[4]
            value = int(field)
            values.append(value)
    return values

# Get the initial values of a signal from a header file.
def get_initial_values(string):
    num_signals = get_num_signals(string)
    values = list()
    for i, l in enumerate(string.split('\n')):
        if 1 <= i <= num_signals:
            field = l.split(' ')[5]
            value = int(field)
            values.append(value)
    return values

# Get the checksums of a signal from a header file.
def get_checksums(string):
    num_signals = get_num_signals(string)
    values = list()
    for i, l in enumerate(string.split('\n')):
        if 1 <= i <= num_signals:
            field = l.split(' ')[6]
            value = int(field)
            values.append(value)
    return values

# Get the block sizes of a signal from a header file.
def get_block_sizes(string):
    num_signals = get_num_signals(string)
    values = list()
    for i, l in enumerate(string.split('\n')):
        if 1 <= i <= num_signals:
            field = l.split(' ')[7]
            value = int(field)
            values.append(value)
    return values

# Get the signal names from a header file.
def get_signal_names(string):
    num_signals = get_num_signals(string)
    values = list()
    for i, l in enumerate(string.split('\n')):
        if 1 <= i <= num_signals:
            value = l.split(' ')[8]
            values.append(value)
    return values

### Evaluation functions

# Construct the binary one-vs-rest confusion matrices, where the columns are the expert labels and the rows are the classifier
# for the given classes.
def compute_one_vs_rest_confusion_matrix(labels, outputs, classes):
    assert np.shape(labels) == np.shape(outputs)

    num_instances = len(labels)
    num_classes = len(classes)

    A = np.zeros((num_classes, 2, 2))
    for i in range(num_instances):
        for j in range(num_classes):
            if labels[i, j] == 1 and outputs[i, j] == 1: # TP
                A[j, 0, 0] += 1
            elif labels[i, j] == 0 and outputs[i, j] == 1: # FP
                A[j, 0, 1] += 1
            elif labels[i, j] == 1 and outputs[i, j] == 0: # FN
                A[j, 1, 0] += 1
            elif labels[i, j] == 0 and outputs[i, j] == 0: # TN
                A[j, 1, 1] += 1

    return A

# Compute macro F-measure.
def compute_f_measure(labels, outputs):
    # Compute confusion matrix.
    classes = sorted(set.union(*map(set, labels)))
    labels = compute_one_hot_encoding(labels, classes)
    outputs = compute_one_hot_encoding(outputs, classes)
    A = compute_one_vs_rest_confusion_matrix(labels, outputs, classes)

    num_classes = len(classes)
    per_class_f_measure = np.zeros(num_classes)
    for k in range(num_classes):
        tp, fp, fn, tn = A[k, 0, 0], A[k, 0, 1], A[k, 1, 0], A[k, 1, 1]
        if 2 * tp + fp + fn > 0:
            per_class_f_measure[k] = float(2 * tp) / float(2 * tp + fp + fn)
        else:
            per_class_f_measure[k] = float('nan')

    if np.any(np.isfinite(per_class_f_measure)):
        macro_f_measure = np.nanmean(per_class_f_measure)
    else:
        macro_f_measure = float('nan')

    return macro_f_measure, per_class_f_measure, classes

# Reorder channels in signal.
def reorder_signal(input_signal, input_channels, output_channels):
    # Do not allow repeated channels with potentially different values in a signal.
    assert(len(set(input_channels)) == len(input_channels))
    assert(len(set(output_channels)) == len(output_channels))

    if input_channels == output_channels:
        output_signal = input_signal
    else:
        input_channels = [channel.strip().casefold() for channel in input_channels]
        output_channels = [channel.strip().casefold() for channel in output_channels]

        input_signal = np.asarray(input_signal)
        num_samples = np.shape(input_signal)[0]
        num_channels = len(output_channels)
        data_type = input_signal.dtype
        output_signal = np.zeros((num_samples, num_channels), dtype=data_type)

        for i, output_channel in enumerate(output_channels):
            for j, input_channel in enumerate(input_channels):
                if input_channel == output_channel:
                    output_signal[:, i] = input_signal[:, j]

    return output_signal

# Pad or truncate signal.
def trim_signal(input_signal, num_samples_trimmed):
    input_signal = np.asarray(input_signal)
    num_samples, num_channels = np.shape(input_signal)
    data_type = input_signal.dtype

    if num_samples == num_samples_trimmed:
        output_signal = input_signal
    else:
        output_signal = np.zeros((num_samples_trimmed, num_channels), dtype=data_type)
        if num_samples < num_samples_trimmed: # Zero-pad the signals.
            output_signal[:num_samples, :] = input_signal
        else: # Truncate the signals.
            output_signal = input_signal[:num_samples_trimmed, :]

    return output_signal

# Compute SNR.
def compute_snr(label_signal, output_signal):
    label_signal = np.asarray(label_signal)
    output_signal = np.asarray(output_signal)

    assert(label_signal.ndim == output_signal.ndim == 1)
    assert(np.size(label_signal) == np.size(output_signal))

    idx_finite_signal = np.isfinite(label_signal)
    label_signal = label_signal[idx_finite_signal]
    output_signal = output_signal[idx_finite_signal]

    idx_nan_signal = np.isnan(output_signal)
    output_signal[idx_nan_signal] = 0

    noise_signal = output_signal - label_signal

    x = np.sum(label_signal**2)
    y = np.sum(noise_signal**2)

    if x > 0 and y > 0:
        snr = 10 * np.log10(x / y)
    elif x > 0 and y == 0:
        snr = float('inf')
    else:
        snr = float('nan')

    return snr

# Compute the mean signal power to median noise power metric.
def compute_snr_median(label_signal, output_signal):
    label_signal = np.asarray(label_signal)
    output_signal = np.asarray(output_signal)

    assert(label_signal.ndim == output_signal.ndim == 1)
    assert(np.size(label_signal) == np.size(output_signal))

    idx_finite_signal = np.isfinite(label_signal)
    label_signal = label_signal[idx_finite_signal]
    output_signal = output_signal[idx_finite_signal]

    idx_nan_signal = np.isnan(output_signal)
    output_signal[idx_nan_signal] = 0

    noise_signal = output_signal - label_signal

    x = np.mean(label_signal**2)
    y = np.median(noise_signal**2)

    if y > 0:
        snr = 10 * np.log10(x / y)
    else:
        snr = float('inf')

    return snr

# Compute a metric inspired by the Kolmogorov-Smirnov test statistic.
def compute_ks_metric(label_signal, output_signal):
    label_signal = np.asarray(label_signal)
    output_signal = np.asarray(output_signal)

    assert(label_signal.ndim == output_signal.ndim == 1)
    assert(np.size(label_signal) == np.size(output_signal))

    idx_finite_signal = np.isfinite(label_signal)
    label_signal = label_signal[idx_finite_signal]
    output_signal = output_signal[idx_finite_signal]

    idx_nan_signal = np.isnan(output_signal)
    output_signal[idx_nan_signal] = 0

    label_signal_cdf = np.cumsum(np.abs(label_signal))
    output_signal_cdf = np.cumsum(np.abs(output_signal))

    if label_signal_cdf[-1] > 0:
        label_signal_cdf = label_signal_cdf / label_signal_cdf[-1]
    if output_signal_cdf[-1] > 0:
        output_signal_cdf = output_signal_cdf / output_signal_cdf[-1]

    goodness_of_fit = 1.0 - np.max(np.abs(label_signal_cdf - output_signal_cdf))

    return goodness_of_fit

# Compute the adaptive signed correlation index (ASCI) metric.
def compute_asci_metric(label_signal, output_signal, beta=0.05):
    label_signal = np.asarray(label_signal)
    output_signal = np.asarray(output_signal)

    assert(label_signal.ndim == output_signal.ndim == 1)
    assert(np.size(label_signal) == np.size(output_signal))

    idx_finite_signal = np.isfinite(label_signal)
    label_signal = label_signal[idx_finite_signal]
    output_signal = output_signal[idx_finite_signal]

    idx_nan_signal = np.isnan(output_signal)
    output_signal[idx_nan_signal] = 0

    if beta <= 0 or beta > 1:
        raise ValueError('The beta value should be greater than 0 and less than or equal to 1.')

    threshold = beta * np.std(label_signal)

    noise_signal = np.abs(label_signal - output_signal)

    discrete_noise = np.zeros_like(noise_signal)
    discrete_noise[noise_signal <= threshold] = 1
    discrete_noise[noise_signal > threshold] = -1

    asci = np.mean(discrete_noise)

    return asci

# Compute a weighted absolute difference metric.
def compute_weighted_absolute_difference(label_signal, output_signal, sampling_frequency):
    label_signal = np.asarray(label_signal)
    output_signal = np.asarray(output_signal)

    assert(label_signal.ndim == output_signal.ndim == 1)
    assert(np.size(label_signal) == np.size(output_signal))

    idx_finite_signal = np.isfinite(label_signal)
    label_signal = label_signal[idx_finite_signal]
    output_signal = output_signal[idx_finite_signal]

    idx_nan_signal = np.isnan(output_signal)
    output_signal[idx_nan_signal] = 0

    from scipy.signal import filtfilt

    m = round(0.1 * sampling_frequency)
    w = filtfilt(np.ones(m), m, label_signal, method='gust')
    w = 1 - 0.5/np.max(w) * w
    n = np.sum(w)

    weighted_absolute_difference_metric = np.sum(np.abs(label_signal-output_signal) * w)/n

    return weighted_absolute_difference_metric

### Other helper functions

# Check if a variable is a number or represents a number.
def is_number(x):
    try:
        float(x)
        return True
    except (ValueError, TypeError):
        return False

# Check if a variable is an integer or represents an integer.
def is_integer(x):
    if is_number(x):
        return float(x).is_integer()
    else:
        return False

# Check if a variable is a finite number or represents a finite number.
def is_finite_number(x):
    if is_number(x):
        return np.isfinite(float(x))
    else:
        return False

# Check if a variable is a NaN (not a number) or represents a NaN.
def is_nan(x):
    if is_number(x):
        return np.isnan(float(x))
    else:
        return False

# Cast a value to an integer if an integer, a float if a non-integer float, and an unknown value otherwise.
def cast_int_float_unknown(x):
    if is_integer(x):
        x = int(x)
    elif is_finite_number(x):
        x = float(x)
    elif is_number(x):
        x = 'Unknown'
    else:
        raise NotImplementedError(f'Unable to cast {x}.')
    return x

# Construct the one-hot encoding of data for the given classes.
def compute_one_hot_encoding(data, classes):
    num_instances = len(data)
    num_classes = len(classes)

    one_hot_encoding = np.zeros((num_instances, num_classes), dtype=np.bool_)
    unencoded_data = list()
    for i, x in enumerate(data):
        for y in x:
            for j, z in enumerate(classes):
                if (y == z) or (is_nan(y) and is_nan(z)):
                    one_hot_encoding[i, j] = 1

    return one_hot_encoding

# %% [markdown]
# ---
# ### prepare_image_data.py
# ---

# %%
#!/usr/bin/env python

# Load libraries.
import argparse
import json
import os
import os.path
import shutil
import sys
from collections import defaultdict

# from helper_code import *

# Parse arguments.
def get_parser():
    description = 'Prepare the ECG image data from ECG-Image-Kit for the Challenge.'
    parser = argparse.ArgumentParser(description=description)
    parser.add_argument('-i', '--input_folder', type=str, required=True)
    parser.add_argument('-o', '--output_folder', type=str, required=True)
    return parser

# Find files.
def find_files(folder, extensions, remove_extension=False, sort=False):
    selected_files = set()
    for root, directories, files in os.walk(folder):
        for file in files:
            extension = os.path.splitext(file)[1]
            if extension in extensions:
                file = os.path.relpath(os.path.join(root, file), folder)
                if remove_extension:
                    file = os.path.splitext(file)[0]
                selected_files.add(file)
    if sort:
        selected_files = sorted(selected_files)
    return selected_files

# Run script.
def run(args):
    # Define variables.
    image_file_types = ['.png', '.jpg', '.jpeg']

    # Find the header files.
    records = find_records(args.input_folder)

    # Find the image files.
    image_files = find_files(args.input_folder, image_file_types)
    record_to_image_files = defaultdict(set)
    for image_file in image_files:
        root, ext = os.path.splitext(image_file)
        record = '-'.join(root.split('-')[:-1])
        basename = os.path.basename(image_file)
        record_to_image_files[record].add(basename)

    # Update the header files and copy signal files.
    for record in records:
        record_path, record_basename = os.path.split(record)
        record_image_files = record_to_image_files[record]

        # Sort the images numerically if numerical and alphanumerically otherwise.
        record_suffixes = [os.path.splitext(image_file)[0].split('-')[-1] for image_file in record_image_files]
        if all(is_number(suffix) for suffix in record_suffixes):
            record_image_files = sorted(record_image_files, key=lambda image_file: float(os.path.splitext(image_file)[0].split('-')[-1]))
        else:
            record_image_files = sorted(record_image_files)

        # Update the header files.
        input_header_file = os.path.join(args.input_folder, record + '.hea')
        output_header_file = os.path.join(args.output_folder, record + '.hea')

        input_header = load_text(input_header_file)
        output_header = ''
        for l in input_header.split('\n'):
            if not l.startswith(substring_images) and l:
                output_header += l + '\n'

        record_image_string = ', '.join(record_image_files)
        output_header += f'{substring_images} {record_image_string}\n'

        input_path = os.path.join(args.input_folder, record_path)
        output_path = os.path.join(args.output_folder, record_path)

        os.makedirs(output_path, exist_ok=True)

        with open(output_header_file, 'w') as f:
            f.write(output_header)

        # Copy the signal and image files if available.
        if os.path.normpath(args.input_folder) != os.path.normpath(args.output_folder):
            relative_path = os.path.split(record)[0]

            signal_files = get_signal_files(output_header_file)
            relative_path = os.path.split(record)[0]
            for signal_file in signal_files:
                input_signal_file = os.path.join(args.input_folder, relative_path, signal_file)
                output_signal_file = os.path.join(args.output_folder, relative_path, signal_file)
                if os.path.isfile(input_signal_file):
                    shutil.copy2(input_signal_file, output_signal_file)

            image_files = get_image_files(output_header_file)
            for image_file in image_files:
                input_image_file = os.path.join(args.input_folder, relative_path, image_file)
                output_image_file = os.path.join(args.output_folder, relative_path, image_file)
                if os.path.isfile(input_image_file):
                    shutil.copy2(input_image_file, output_image_file)

# if __name__=='__main__':
#     run(get_parser().parse_args(sys.argv[1:]))

# %% [markdown]
# ---
# ### prepare_ptbxl_data.py
# ---

# %%
#!/usr/bin/env python

# Load libraries.
import argparse
import ast
import numpy as np
import os
import os.path
import pandas as pd
import shutil
import sys

# from helper_code import *

# Parse arguments.
def get_parser():
    description = 'Prepare the PTB-XL database for use in the Challenge.'
    parser = argparse.ArgumentParser(description=description)
    parser.add_argument('-i', '--input_folder', type=str, required=True)
    parser.add_argument('-pd', '--ptbxl_database_file', type=str, required=True) # ptbxl_database.csv
    parser.add_argument('-pm', '--ptbxl_mapping_file', type=str, required=True) # scp_statements.csv
    parser.add_argument('-sd', '--sl_database_file', type=str, required=True) # 12sl_statements.csv
    parser.add_argument('-sm', '--sl_mapping_file', type=str, required=True) # 12slv23ToSNOMED.csv
    parser.add_argument('-o', '--output_folder', type=str, required=True)
    return parser

# Run script.
def run(args):
    # Assign each class to a superclass; these commands were adapted from the PhysioNet project documentation.
    df_ptbxl_mapping = pd.read_csv(args.ptbxl_mapping_file, index_col=0)
    subclass_to_superclass = dict()
    for i, row in df_ptbxl_mapping.iterrows():
        if row['diagnostic'] == 1:
            subclass_to_superclass[i] = row['diagnostic_class']

    def assign_superclass(subclasses):
        superclasses = list()
        for subclass in subclasses:
            if subclass in subclass_to_superclass:
                superclass = subclass_to_superclass[subclass]
                if superclass not in superclasses:
                    superclasses.append(superclass)
        return superclasses

    # Load the PTB-XL labels.
    df_ptbxl_database = pd.read_csv(args.ptbxl_database_file, index_col='ecg_id')
    df_ptbxl_database.scp_codes = df_ptbxl_database.scp_codes.apply(lambda x: ast.literal_eval(x))

    # Map the PTB-XL classes to superclasses.
    df_ptbxl_database['diagnostic_superclass'] = df_ptbxl_database.scp_codes.apply(assign_superclass)

    # Load the 12SL labels.
    df_sl_database = pd.read_csv(args.sl_database_file, index_col='ecg_id')

    # Map the 12SL classes to the PTB-XL classes for the following acute myocardial infarction (MI) classes; PTB-XL does not include
    # a separate acute MI class.
    df_sl_mapping = pd.read_csv(args.sl_mapping_file, index_col='StatementNumber')

    acute_mi_statements = set([821, 822, 823, 827, 829, 902, 903, 904, 963, 964, 965, 966, 967, 968])
    acute_mi_classes = set()
    for statement in acute_mi_statements:
        if statement in df_sl_mapping.index:
            acute_mi_classes.add(df_sl_mapping.loc[statement]['Acronym'])

    # Identify the header files.
    records = find_records(args.input_folder)

    # Update the header files to include demographics data and labels and copy the signal files unchanged.
    for record in records:

        # Extract the demographics data.
        record_path, record_basename = os.path.split(record)
        ecg_id = int(record_basename.split('_')[0])
        row = df_ptbxl_database.loc[ecg_id]

        recording_date_string = row['recording_date']
        date_string, time_string = recording_date_string.split(' ')
        yyyy, mm, dd = date_string.split('-')
        date_string = f'{dd}/{mm}/{yyyy}'

        age = row['age']
        age = cast_int_float_unknown(age)

        sex = row['sex']
        if sex == 0:
            sex = 'Male'
        elif sex == 1:
            sex = 'Female'
        else:
            sex = 'Unknown'

        height = row['height']
        height = cast_int_float_unknown(height)

        weight = row['weight']
        weight = cast_int_float_unknown(weight)

        scp_code_dict = row['scp_codes']
        scp_codes = [scp_code for scp_code in scp_code_dict if scp_code_dict[scp_code] >= 0]
        superclasses = row['diagnostic_superclass']

        if ecg_id in df_sl_database.index:
            sl_codes = df_sl_database.loc[ecg_id]['statements']
        else:
            sl_codes = list()

        labels = list()
        if 'NORM' in superclasses:
            labels.append('NORM')
        if any(c in sl_codes for c in acute_mi_classes):
            labels.append('Acute MI')
        if 'MI' in superclasses and not any(c in sl_codes for c in acute_mi_classes):
            labels.append('Old MI')
        if 'STTC' in superclasses:
            labels.append('STTC')
        if 'CD' in superclasses:
            labels.append('CD')
        if 'HYP' in superclasses:
            labels.append('HYP')
        if 'PAC' in scp_codes:
            labels.append('PAC')
        if 'PVC' in scp_codes:
            labels.append('PVC')
        if 'AFIB' in scp_codes or 'AFLT' in scp_codes:
            labels.append('AFIB/AFL')
        if 'STACH' in scp_codes or 'SVTAC' in scp_codes or 'PSVT' in scp_codes:
            labels.append('TACHY')
        if 'SBRAD' in scp_codes:
            labels.append('BRADY')
        labels = ', '.join(labels)

        # Update the header file.
        input_header_file = os.path.join(args.input_folder, record + '.hea')
        output_header_file = os.path.join(args.output_folder, record + '.hea')

        input_path = os.path.join(args.input_folder, record_path)
        output_path = os.path.join(args.output_folder, record_path)

        os.makedirs(output_path, exist_ok=True)

        with open(input_header_file, 'r') as f:
            input_header = f.read()

        lines = input_header.split('\n')
        record_line = ' '.join(lines[0].strip().split(' ')[:4]) + '\n'
        signal_lines = '\n'.join(l.strip() for l in lines[1:] \
            if l.strip() and not l.startswith('#')) + '\n'
        comment_lines = '\n'.join(l.strip() for l in lines[1:] \
            if l.startswith('#') and not any((l.startswith(x) for x in ('# Age:', '# Sex:', '# Height:', '# Weight:', f'{substring_labels}')))) + '\n'

        record_line = record_line.strip() + f' {time_string} {date_string} ' + '\n'
        signal_lines = signal_lines.strip() + '\n'
        comment_lines = comment_lines.strip() + f'# Age: {age}\n# Sex: {sex}\n# Height: {height}\n# Weight: {weight}\n{substring_labels} {labels}\n'

        output_header = record_line + signal_lines + comment_lines

        with open(output_header_file, 'w') as f:
            f.write(output_header)

        # Copy the signal files if the input and output folders are different.
        if os.path.normpath(args.input_folder) != os.path.normpath(args.output_folder):
            relative_path = os.path.split(record)[0]

            signal_files = get_signal_files(input_header_file)
            for signal_file in signal_files:
                input_signal_file = os.path.join(args.input_folder, relative_path, signal_file)
                output_signal_file = os.path.join(args.output_folder, relative_path, signal_file)
                if os.path.isfile(input_signal_file):
                    shutil.copy2(input_signal_file, output_signal_file)

# if __name__=='__main__':
    # run(get_parser().parse_args(sys.argv[1:]))

# %% [markdown]
# ---
# ### remove_hidden_data.py
# ---

# %%
#!/usr/bin/env python

# Load libraries.
import argparse
import os
import os.path
import shutil
import sys

# from helper_code import *

# Parse arguments.
def get_parser():
    description = 'Remove hidden data.'
    parser = argparse.ArgumentParser(description=description)
    parser.add_argument('-i', '--input_folder', type=str, required=True)
    parser.add_argument('-w', '--include_waveforms', action='store_true')
    parser.add_argument('-l', '--include_labels', action='store_true')
    parser.add_argument('-m', '--include_images', action='store_true')
    parser.add_argument('-o', '--output_folder', type=str, required=True)
    return parser

# Run script.
def run(args):
    # Identify header files.
    records = find_records(args.input_folder)

    # Update header files and copy signal files.
    for record in records:
        record_path, record_basename = os.path.split(record)

        input_header_file = os.path.join(args.input_folder, record + '.hea')
        output_header_file = os.path.join(args.output_folder, record + '.hea')

        input_header = load_text(input_header_file)
        output_header = ''

        num_signals = get_num_signals(input_header)
        for i, l in enumerate(input_header.split('\n')):
            arrs = l.split(' ')
            if i == 0:
                output_header += ' '.join(arrs[:4]) + '\n'
            elif 1 <= i <= num_signals:
                output_header += ' '.join(arrs[:5] + ['', '', ''] + [arrs[8]]) + '\n'
            elif l.startswith(substring_labels):
                if args.include_labels:
                    output_header += l + '\n'
            elif l.startswith(substring_images):
                if args.include_images:
                    output_header += l + '\n'

        input_path = os.path.join(args.input_folder, record_path)
        output_path = os.path.join(args.output_folder, record_path)

        os.makedirs(output_path, exist_ok=True)

        with open(output_header_file, 'w') as f:
            f.write(output_header)

        relative_path = os.path.split(record)[0]

        if args.include_waveforms and os.path.normpath(args.input_folder) != os.path.normpath(args.output_folder):
            signal_files = get_signal_files(input_header_file)
            for signal_file in signal_files:
                input_signal_file = os.path.join(args.input_folder, relative_path, signal_file)
                output_signal_file = os.path.join(args.output_folder, relative_path, signal_file)
                if os.path.isfile(input_signal_file):
                    shutil.copy2(input_signal_file, output_signal_file)
        elif not args.include_waveforms and os.path.normpath(args.input_folder) == os.path.normpath(args.output_folder):
            signal_files = get_signal_files(input_header_file)
            for signal_file in signal_files:
                input_signal_file = os.path.join(args.input_folder, relative_path, signal_file)
                output_signal_file = os.path.join(args.output_folder, relative_path, signal_file)
                if os.path.isfile(output_signal_file):
                    os.remove(output_signal_file)

        if args.include_images:
            image_files = get_image_files(input_header_file)
            for image_file in image_files:
                input_image_file = os.path.join(args.input_folder, relative_path, image_file)
                output_image_file = os.path.join(args.output_folder, relative_path, image_file)
                if os.path.isfile(input_image_file):
                    shutil.copy2(input_image_file, output_image_file)

# if __name__=='__main__':
#     run(get_parser().parse_args(sys.argv[1:]))

# %% [markdown]
# ---
# ### run_model.py
# ---

# %%
#!/usr/bin/env python

# Please do *not* edit this script. Changes will be discarded so that we can run the trained models consistently.

# This file contains functions for running models for the Challenge. You can run it as follows:
#
#   python run_model.py -d data -m model -o outputs -v
#
# where 'data' is a folder containing the Challenge data, 'models' is a folder containing the your trained models, 'outputs' is a
# folder for saving your models' outputs, and -v is an optional verbosity flag.

import argparse
import os
import sys

# from helper_code import *
# from team_code import load_models, run_models

# Parse arguments.
def get_parser():
    description = 'Run the trained Challenge models.'
    parser = argparse.ArgumentParser(description=description)
    parser.add_argument('-d', '--data_folder', type=str, required=True)
    parser.add_argument('-m', '--model_folder', type=str, required=True)
    parser.add_argument('-o', '--output_folder', type=str, required=True)
    parser.add_argument('-v', '--verbose', action='store_true')
    parser.add_argument('-f', '--allow_failures', action='store_true')
    return parser

# Run the code.
def run(args):
    # Load the models.
    if args.verbose:
        print('Loading the Challenge model...')

    # You can use these functions to perform tasks, such as loading your models, that you only need to perform once.
    digitization_model, classification_model = load_models(args.model_folder, args.verbose) ### Teams: Implement this function!!!

    # Find the Challenge data.
    if args.verbose:
        print('Finding the Challenge data...')

    records = find_records(args.data_folder)
    num_records = len(records)

    if num_records==0:
        raise Exception('No data were provided.')

    # Create a folder for the Challenge outputs if it does not already exist.
    os.makedirs(args.output_folder, exist_ok=True)

    # Run the team's models on the Challenge data.
    if args.verbose:
        print('Running the Challenge model(s) on the Challenge data...')

    # Iterate over the records.
    for i in range(num_records):
        if args.verbose:
            width = len(str(num_records))
            print(f'- {i+1:>{width}}/{num_records}: {records[i]}...')

        data_record = os.path.join(args.data_folder, records[i])
        output_record = os.path.join(args.output_folder, records[i])

        # Run the models. Allow or disallow the models to fail on some of the data, which can be helpful for debugging.
        try:
            signals, labels = run_models(data_record, digitization_model, classification_model, args.verbose) ### Teams: Implement this function!!!
        except:
            if args.allow_failures:
                if args.verbose:
                    print('... failed.')
                signal = None
                labels = None
            else:
                raise

        # Save Challenge outputs.
        output_path = os.path.split(output_record)[0]
        os.makedirs(output_path, exist_ok=True)

        data_header = load_header(data_record)
        save_header(output_record, data_header)

        if signals is not None:
            comments = [l for l in data_header.split('\n') if l.startswith('#')]
            save_signals(output_record, signals, comments)
        if labels is not None:
            save_labels(output_record, labels)

    if args.verbose:
        print('Done.')

# if __name__ == '__main__':
#     run(get_parser().parse_args(sys.argv[1:]))

# %% [markdown]
# ---
# ### simple_cnn.py
# ---

# %%
"""Simple convolutional neural network"""

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder

# Define a simple CNN model
class SimpleCNN(nn.Module):
    def __init__(self, list_of_classes):
        super(SimpleCNN, self).__init__()
        self.list_of_classes = list_of_classes
        self.num_classes = len(self.list_of_classes)
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64*53*68, 512)          # Adjusted  to input size (425, 550)
        self.fc2 = nn.Linear(512, self.num_classes)  # 11 output classes for multilabel classification

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = self.pool(torch.relu(self.conv3(x)))
        x = x.view(-1, x.shape[1] * x.shape[2]* x.shape[3])
        x = torch.relu(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))  # Sigmoid activation for multilabel classification
        return x

# %% [markdown]
# ---
# ### train_model.py
# ---

# %%
#!/usr/bin/env python

# Please do *not* edit this script. Changes will be discarded so that we can train the models consistently.

# This file contains functions for training models for the Challenge. You can run it as follows:
#
#   python train_model.py -d data -m model -v
#
# where 'data' is a folder containing the Challenge data, 'model' is a folder for saving your models, and , and -v is an optional
# verbosity flag.

import argparse
import sys

# from helper_code import *
# from team_code import train_models

# Parse arguments.
def get_parser():
    description = 'Train the Challenge models.'
    parser = argparse.ArgumentParser(description=description)
    parser.add_argument('-d', '--data_folder', type=str, required=True)
    parser.add_argument('-m', '--model_folder', type=str, required=True)
    parser.add_argument('-v', '--verbose', action='store_true')
    return parser

# Run the code.
def run(args):
    train_models(args.data_folder, args.model_folder, args.verbose) ### Teams: Implement this function!!!

# if __name__ == '__main__':
#     run(get_parser().parse_args(sys.argv[1:]))

# %% [markdown]
# ---
# ### team_code.py
# ---

# %%
#!/usr/bin/env python

# Edit this script to add your team's code. Some functions are *required*, but you can edit most parts of the required functions,
# change or remove non-required functions, and add your own functions.

################################################################################
#
# Optional libraries, functions, and variables. You can change or remove them.
#
################################################################################

import joblib
import numpy as np
import os
import random
import shutil
import sys
import torch
import torch.nn as nn
import torch.optim as optim

from PIL import Image
from collections import OrderedDict
# from data_loader import get_training_and_validation_loaders
from functools import partial
# from helper_code import *
from matplotlib import pyplot as plt
# from simple_cnn import SimpleCNN
from sklearn.metrics import average_precision_score,precision_recall_curve,roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split
from torch import Tensor
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import Dataset
from torchvision import transforms
from torchvision.datasets import ImageFolder
from tqdm import tqdm
from typing import Callable, Optional

# DEVICE = 'cuda:0' if torch.cuda.is_available() else 'cpu'
# DEVICE = "cuda"

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
EPOCHS = 10
CLASSIFICATION_THRESHOLD=0.5
CLASSIFICATION_DISTANCE_TO_MAX_THRESHOLD=0.1
LIST_OF_ALL_LABELS=['NORM', 'Acute MI', 'Old MI', 'STTC', 'CD', 'HYP', 'PAC', 'PVC', 'AFIB/AFL', 'TACHY', 'BRADY']
RESIZE_TEST_IMAGES=(425, 550)
OPTIM_LR=1e-3
OPTIM_WEIGHT_DECAY=1e-4
SCHEDULER_STEP_SIZE=7
SCHEDULER_GAMMA=0.1

################################################################################
#
# Required functions. Edit these functions to add your code, but do not change the arguments of the functions.
#
################################################################################

# Train your models. This function is *required*. You should edit this function to add your code, but do *not* change the arguments
# of this function. If you do not train one of the models, then you can return None for the model.

def train_models(data_folder, model_folder, verbose):

    print(DEVICE)
    # Find the data files.
    if verbose:
        print('Finding the Challenge data...')

    records = find_records(data_folder)
    num_records = len(records)

    if num_records == 0:
        raise FileNotFoundError('No data were provided.')

    # Extract the data...
    if verbose:
        print('Loading the data...')

    classification_images = list() # list of image paths
    classification_labels = list() # list of lists of strings

    # Iterate over the records.
    for i in range(num_records):
        if verbose:
            width = len(str(num_records))
            print(f'- {i+1:>{width}}/{num_records}: {records[i]}...')

        record = os.path.join(data_folder, records[i])
        record_parent_folder=os.path.dirname(record)

        # Some images may not be labeled, so we'll exclude those
        labels = load_labels(record)
        if labels:

            # I'm imposing a further condition: the label strings should be nonempty
            nonempty_labels=[l for l in labels if l != '']
            if nonempty_labels != []:

                # Add the first image to the list
                images = get_image_files(record)
                classification_images.append(os.path.join(record_parent_folder, images[0]) )
                classification_labels.append(nonempty_labels)

    # We expect some images to be labeled for classification.
    if not classification_labels:
        raise Exception('There are no labels for the data.')

    # Fix an ordering of the labels
    num_classes=len(LIST_OF_ALL_LABELS)

    # Train the models.
    if verbose:
        print('Training the models on the data...')

    #=====================
    # Classification task
    #=====================

    # Split the training set into "training" and "validation" subsets, returning them as DataLoaders
    training_loader, validation_loader \
        = get_training_and_validation_loaders(LIST_OF_ALL_LABELS, classification_images, classification_labels)

    # Initialize a model
    classification_model = SimpleCNN(LIST_OF_ALL_LABELS).to(DEVICE)
    for param in classification_model.parameters(): # fine tune all the layers
        param.requires_grad = True

    loss = nn.BCELoss() # binary cross entropy loss for multilabel classification
    opt = optim.Adam(classification_model.parameters(), lr=OPTIM_LR, weight_decay=OPTIM_WEIGHT_DECAY)
    scheduler = StepLR(opt, step_size=SCHEDULER_STEP_SIZE, gamma=SCHEDULER_GAMMA)

    N_loss = []
    N_loss_valid = []
    train_auprc = []
    valid_auprc = []
    train_auroc= []
    valid_auroc = []
    f1_train = []
    f1_valid = []

    plot_folder=os.path.join(model_folder, "training_figures")
    os.makedirs(plot_folder, exist_ok=True)

    # Filename to save the final weights to
    final_weights=None

    # Now let's train!
    for epoch in range(EPOCHS):

        # Initialization of variables for plotting the progress
         N_item_sum = 0
         N_item_sum_valid = 0
         targets_train = []
         outputs_train = []
         targets_valid = []
         outputs_valid = []

         ### Training part
         if verbose:
            print(f"============================[{epoch}]============================")
         classification_model.train()
         for i, (image, label) in enumerate(training_loader):
             opt.zero_grad()

             image = image.float().to(DEVICE)
             label = label.to(torch.float).to(DEVICE)
             prediction = classification_model(image)

             # loss
             N = loss(prediction,label)
             N.backward()
             N_item = N.item()
             N_item_sum += N_item

             # gradient clipping plus optimizer
             torch.nn.utils.clip_grad_norm_(classification_model.parameters(), max_norm=10)
             opt.step()
             if verbose:
                print(f"Epoch: {epoch}, Iteration: {i}, Loss: {N_item}")

             targets_train.append(label.data.cpu().numpy()) #target[:,0]
             outputs_train.append(prediction.data.cpu().numpy())

         ### Validation part
         classification_model.eval()
         with torch.no_grad():
          for j, (image, label) in enumerate(validation_loader):
                 image = image.float().to(DEVICE)
                 label = label.to(torch.float).to(DEVICE)
                 prediction = classification_model(image)

                 N = loss(prediction,label)
                 N_item = N.item()
                 N_item_sum_valid += N.item()

                 targets_valid.append(label.data.cpu().numpy()) #target[:,0]
                 outputs_valid.append(prediction.data.cpu().numpy())
                 print(f"Epoch: {epoch}, Valid Iteration: {j}, Loss: {N_item}")

         scheduler.step()

         # Logging the outputs and targets to caluclate auprc and auroc
         targets_train = np.concatenate(targets_train, axis=0).T
         outputs_train = np.concatenate(outputs_train, axis=0).T
         targets_valid = np.concatenate(targets_valid, axis=0).T
         outputs_valid = np.concatenate(outputs_valid, axis=0).T

         auprc_t = average_precision_score(y_true=targets_train, y_score=outputs_train)
         auroc_t = roc_auc_score(y_true=targets_train, y_score=outputs_train)
         auprc_v = average_precision_score(y_true=targets_valid, y_score=outputs_valid)
         auroc_v = roc_auc_score(y_true=targets_valid, y_score=outputs_valid)

         train_auprc.append(auprc_t)
         train_auroc.append(auroc_t)
         valid_auprc.append(auprc_v)
         valid_auroc.append(auroc_v)

         N_loss.append(N_item_sum/i)
         N_loss_valid.append(N_item_sum_valid/j)

         # saving loss function after each epoch so you can look on progress
         fig = plt.figure()
         plt.plot(N_loss, label="train")
         plt.plot(N_loss_valid, label="valid")
         plt.title("Loss function")
         plt.xlabel('epoch')
         plt.ylabel('loss')
         plt.grid()
         plt.legend()
         plt.savefig(os.path.join(plot_folder, "loss.png"))
         plt.close()

         fig = plt.figure()
         plt.plot(train_auprc, label="train auprc")
         plt.plot(valid_auprc, label="valid auprc")
         plt.plot(train_auroc, label="train auroc")
         plt.plot(valid_auroc, label="valid auroc")

         plt.title("AUPRC and AUROC")
         plt.xlabel('epoch')
         plt.ylabel('Performace')
         plt.grid()
         plt.legend()
         plt.savefig(os.path.join(plot_folder, "auroc_auprc.png"))
         plt.close()

         ### save model after each epoch
         file_path = os.path.join(model_folder, "model_weights_" + str(epoch) + ".pth")
         torch.save(classification_model.state_dict(), file_path)

         # If this is the last epoch, then the weights of the model will be saved to this file
         final_weights = file_path

    # Create a folder for the models if it does not already exist.
    os.makedirs(model_folder, exist_ok=True)

    # Save the models.
    save_classification_model(model_folder, LIST_OF_ALL_LABELS, final_weights)

    if verbose:
        print('Done.')
        print()

# Load your trained models. This function is *required*. You should edit this
# function to add your code, but do *not* change the arguments of this
# function. If you do not train one of the models, then you can return None for
# the model.
def load_models(model_folder, verbose):
    digitization_model = None

    classes_filename = os.path.join(model_folder, 'classes.txt')
    classes = joblib.load(classes_filename)

    classification_model = SimpleCNN(classes).to(DEVICE) # instantiate a new copy of the model
    classification_filename = os.path.join(model_folder, "classification_model.pth")
    classification_model.load_state_dict(torch.load(classification_filename))

    return digitization_model, classification_model

# Run your trained digitization model. This function is *required*. You should edit this function to add your code, but do *not*
# change the arguments of this function. If you did not train one of the models, then you can return None for the model.
def run_models(record, digitization_model, classification_model, verbose):

    # Run the digitization model; if you did not train this model, then you can set signal = None.
    signal = None

    # Run the classification model.
    classes = classification_model.list_of_classes

    # Open the image:
    record_parent_folder=os.path.dirname(record)
    image_files=get_image_files(record)
    image_path=os.path.join(record_parent_folder, image_files[0])
    img = Image.open(image_path)
    # FIXME: repeated code---maybe factor out opening the image from a record
    if img.mode != 'RGB':
        img = img.convert('RGB')

    # transform the image and make it suitable as input
    img = transforms.Resize(RESIZE_TEST_IMAGES)(img)
    img = transforms.ToTensor()(img)
    img = transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])(img)
    img = img.unsqueeze(0)

    # send it to the GPU if necessary
    img = img.float().to(DEVICE)

    classification_model.eval()
    with torch.no_grad():
        probabilities = torch.squeeze(classification_model(img), 0).tolist()
        predictions=list()
        for i in range(len(classes)):
            if probabilities[i] >= CLASSIFICATION_THRESHOLD:
                predictions.append(classes[i])

    # backup if none is over the threshold: use the max
    if predictions==[]:
        highest_probability=max(probabilities)
        for i in range(len(classes)):
            if abs(highest_probability - probabilities[i]) <= CLASSIFICATION_DISTANCE_TO_MAX_THRESHOLD:
                predictions.append(classes[i])

    return signal, predictions

#########################################################################################
#
# Optional functions. You can change or remove these functions and/or add new functions.
#
#########################################################################################

# Extract features.
def extract_features(record):
    images = load_images(record)
    mean = 0.0
    std = 0.0
    for image in images:
        image = np.asarray(image)
        mean += np.mean(image)
        std += np.std(image)
    return np.array([mean, std])

# Save your trained models.
def save_classification_model(model_folder,
                list_of_classes=None,
                final_weights=None):

    if final_weights is not None:
        classes=filename = os.path.join(model_folder, 'classes.txt')
        joblib.dump(list_of_classes, filename, protocol=0)

        # copy the file with the final weights to the model path
        model_filename=os.path.join(model_folder, "classification_model.pth")
        shutil.copyfile(final_weights, model_filename)

# %% [markdown]
# ---
# ### data_loader.py
# ---

# %%
from PIL import Image
import torch
from torch.utils.data import Dataset
from tqdm import tqdm
from torchvision import transforms
from sklearn.model_selection import train_test_split

# from helper_code import *

#===================================
# Parameters (configure stuff here)
#===================================

RESIZE_TO_DIMENSIONS=(425, 550)                             # resize all images to these dimensions during training
TRANSFORM_TRAINING_IMAGES=transforms.RandomHorizontalFlip() # apply this to each training image
IMAGE_MODE='RGB'                                            # set all images to this mode
RANDOM_STATE=42                                             # number for repeatable pseudorandomness

#=========
# Classes
#=========


class ECGImageDataset(Dataset):
    """Map-style dataset that yields (image, label) pairs. In this context,
       each "label" in the (image, label) tuple will really be a vector encoding
       multiple dx labels, while each "image" will be an image path.

       Initialize this with
        - a list of all possible class labels in a fixed ordering,
        - a boolean value saying whether this is a training set or not,
        - a list of paths (as strings), and
        - a list of lists of labels (as strings).
       """

    def __init__(self, list_of_all_classes:list, is_training:bool,
                    image_paths:list, image_labels:list):

        self.list_of_all_classes=list_of_all_classes
        self.num_classes = len(self.list_of_all_classes)
        # Inverse of list_of_all_classes: look up index by name
        self.class_to_index=dict()
        for i in range(self.num_classes):
            self.class_to_index[list_of_all_classes[i]]=i

        self.is_training=is_training

        self.image_paths=image_paths
        self.image_labels=image_labels

        # How to transform images
        inner_transformations = [TRANSFORM_TRAINING_IMAGES] if self.is_training else []
        transformations = [transforms.Resize(RESIZE_TO_DIMENSIONS)] \
                          + inner_transformations \
                          + [transforms.ToTensor(), transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])]
        self.transform_images = transforms.Compose(transformations)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        """index --> (image, label_vector)."""

        # First the image
        our_image = Image.open(self.image_paths[idx])
        if our_image.mode != IMAGE_MODE: # e.g. RGB
            our_image = our_image.convert(IMAGE_MODE)
        our_image = self.transform_images(our_image)

        # Next the labels

        #     Our dataset will encode each label not as a list of strings but as a vector,
        #     one index for each class. Thus we have to convert a list like
        #       ["THING1", "THING2", "THING3"]
        #     into a vector like
        #       [0,1,0,1,1,0].

        label_strings = self.image_labels[idx]
        our_label_vector = [0] * self.num_classes
        for l in label_strings: # labels assigned to this index
            our_label_vector[self.class_to_index[l]] = 1

        return our_image, our_label_vector

    @staticmethod
    def collate_fn(batch):
        """Batch of pairs -> pair of tensors representing the batch"""
        images, labels = tuple(zip(*batch))
        images = torch.stack(images, dim=0)
        labels = torch.as_tensor(labels)
        return images, labels


def get_training_and_validation_loaders(list_of_all_classes, image_path_list, label_names_list):
    """
    Given  a list `list_of_all_classes` of all class labels in the dataset,
    `image_path_list` (a list of image paths), and `label_names_list` (a list
    of _lists_ of label names corresponding to the images), return the pair
    `(training_loader, validation_loader)` which can be used to train/validate
    a model.

    """

    # Divide the dataset into training and validation sets
    training_images, validation_images, \
    training_classes, validation_classes, \
        = train_test_split(image_path_list,
                           label_names_list,
                           test_size=0.2,
                           random_state=RANDOM_STATE,
                           shuffle=True)

    # Dataset for training
    train_dataset=ECGImageDataset(list_of_all_classes=list_of_all_classes,
                                  is_training=True,
                                  image_paths=training_images,
                                  image_labels=training_classes)

    # Dataset for training
    validation_dataset=ECGImageDataset(list_of_all_classes=list_of_all_classes,
                                       is_training=False,
                                       image_paths=validation_images,
                                       image_labels=validation_classes)

    # Dataloader for training
    training_loader = torch.utils.data.DataLoader(train_dataset,
                                                  batch_size=4,
                                                  shuffle=True,
                                                  pin_memory=True,
                                                  num_workers=8,
                                                  drop_last=True,
                                                  collate_fn=train_dataset.collate_fn)

    # DataLoader for validation
    validation_loader = torch.utils.data.DataLoader(validation_dataset,
                                                    batch_size=4,
                                                    shuffle=False, # note this differs
                                                    pin_memory=True,
                                                    num_workers=8,
                                                    drop_last=True,
                                                    collate_fn=validation_dataset.collate_fn)

    return training_loader, validation_loader

# %% [markdown]
# ---
# # Utilities
# ---

# %%
# a function to print the size of the files in MB in all the subdirectories when a file path is given

# %%
# prompt: # a function to print the size of the files in MB in all the subdirectories when a file path is given

def print_folder_sizes(root_path):
  """
  Prints the size of the files in MB in all the subdirectories when a file path is given.

  Args:
    root_path (str): The path to the root directory.
  """
  for dirpath, dirnames, filenames in os.walk(root_path):
    folder_size = 0
    for filename in filenames:
      filepath = os.path.join(dirpath, filename)
      folder_size += os.path.getsize(filepath)
    if folder_size > 0:
      print(f"{dirpath}: {(folder_size / (1024 * 1024)):.2f} MB")

# %% [markdown]
# ---
# # Training
# ---

# %% [markdown]
# This is the function call stack for the following command.
# `python train_model.py -d training_data -m model`
#
# 1. train_model.py
#   - run()
#
#   2. team_code.py
#     - train_models()
#
#          3.
#          - get_training_and_validation_loaders()
#
#          -

# %% [markdown]
# I ran the below line with device=cuda:0

# %%
#!/usr/bin/env python

# Edit this script to add your team's code. Some functions are *required*, but you can edit most parts of the required functions,
# change or remove non-required functions, and add your own functions.

################################################################################
#
# Optional libraries, functions, and variables. You can change or remove them.
#
################################################################################

import joblib
import numpy as np
import os
import random
import shutil
import sys
import torch
import torch.nn as nn
import torch.optim as optim

from PIL import Image
from collections import OrderedDict
# from data_loader import get_training_and_validation_loaders
from functools import partial
# from helper_code import *
from matplotlib import pyplot as plt
# from simple_cnn import SimpleCNN
from sklearn.metrics import average_precision_score,precision_recall_curve,roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split
from torch import Tensor
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import Dataset
from torchvision import transforms
from torchvision.datasets import ImageFolder
from tqdm import tqdm
from typing import Callable, Optional

DEVICE = 'cuda:0' if torch.cuda.is_available() else 'cpu'
# DEVICE = "cuda"

# %% [markdown]
# ---
# ### configuration
# ---

# %%
# DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
EPOCHS = 1
CLASSIFICATION_THRESHOLD=0.5
CLASSIFICATION_DISTANCE_TO_MAX_THRESHOLD=0.1
LIST_OF_ALL_LABELS=['NORM', 'Acute MI', 'Old MI', 'STTC', 'CD', 'HYP', 'PAC', 'PVC', 'AFIB/AFL', 'TACHY', 'BRADY']
RESIZE_TEST_IMAGES=(425, 550)
OPTIM_LR=1e-3
OPTIM_WEIGHT_DECAY=1e-4
SCHEDULER_STEP_SIZE=7
SCHEDULER_GAMMA=0.1

# %%
verbose = True

# folder paths
data_folder = "/content/train_data_0"
model_folder = "/content/model"

os.makedirs(model_folder, exist_ok=True)

# %% [markdown]
# ---
# ### training code
# ---

# %%
print(DEVICE)
# Out:
# cpu

# %%
records = find_records(data_folder)
num_records = len(records)

if num_records == 0:
    raise FileNotFoundError('No data were provided.')
else:
    print(f'Found {num_records} records.')
# Out:
# Found 987 records.

# %%
classification_images = list()  # list of image paths
classification_labels = list()  # list of lists of strings

# Iterate over the records.
for i in range(num_records):
    if verbose:
        width = len(str(num_records))
        print(f'- {i + 1:>{width}}/{num_records}: {records[i]}...')

    record = os.path.join(data_folder, records[i])
    record_parent_folder = os.path.dirname(record)

    # Some images may not be labeled, so we'll exclude those
    labels = load_labels(record)
    if labels:

        # I'm imposing a further condition: the label strings should be nonempty
        nonempty_labels = [l for l in labels if l != '']
        if nonempty_labels != []:

            # Add the first image to the list
            images = get_image_files(record)
            classification_images.append(os.path.join(record_parent_folder, images[0]))
            classification_labels.append(nonempty_labels)
# Out:
# -   1/987: 00001_hr...
# -   2/987: 00002_hr...
# -   3/987: 00003_hr...
# -   4/987: 00004_hr...
# -   5/987: 00005_hr...
# -   6/987: 00006_hr...
# -   7/987: 00007_hr...
# -   8/987: 00008_hr...
# -   9/987: 00009_hr...
# -  10/987: 00010_hr...
# -  11/987: 00011_hr...
# -  12/987: 00012_hr...
# -  13/987: 00013_hr...
# -  14/987: 00014_hr...
# -  15/987: 00015_hr...
# -  16/987: 00016_hr...
# -  17/987: 00017_hr...
# -  18/987: 00018_hr...
# -  19/987: 00019_hr...
# -  20/987: 00020_hr...
# -  21/987: 00021_hr...
# -  22/987: 00022_hr...
# -  23/987: 00023_hr...
# -  24/987: 00024_hr...
# -  25/987: 00025_hr...
# -  26/987: 00026_hr...
# -  27/987: 00027_hr...
# -  28/987: 00028_hr...
# -  29/987: 00029_hr...
# -  30/987: 00030_hr...
# -  31/987: 00031_hr...
# -  32/987: 00032_hr...
# -  33/987: 00033_hr...
# -  34/987: 00034_hr...
# -  35/987: 00035_hr...
# -  36/987: 00036_hr...
# -  37/987: 00037_hr...
# -  38/987: 00038_hr...
# -  39/987: 00039_hr...
# -  40/987: 00040_hr...
# -  41/987: 00041_hr...
# -  42/987: 00042_hr...
# -  43/987: 00043_hr...
# -  44/987: 00044_hr...
# -  45/987: 00045_hr...
# -  46/987: 00046_hr...
# -  47/987: 00047_hr...
# -  48/987: 00048_hr...
# -  49/987: 00049_hr...
# -  50/987: 00050_hr...
# -  51/987: 00051_hr...
# -  52/987: 00052_hr...
# -  53/987: 00053_hr...
# -  54/987: 00054_hr...
# -  55/987: 00055_hr...
# -  56/987: 00056_hr...
# -  57/987: 00057_hr...
# -  58/987: 00058_hr...
# -  59/987: 00059_hr...
# -  60/987: 00060_hr...
# -  61/987: 00061_hr...
# -  62/987: 00062_hr...
# -  63/987: 00063_hr...
# -  64/987: 00064_hr...
# -  65/987: 00065_hr...
# -  66/987: 00066_hr...
# -  67/987: 00067_hr...
# -  68/987: 00068_hr...
# -  69/987: 00069_hr...
# -  70/987: 00070_hr...
# -  71/987: 00071_hr...
# -  72/987: 00072_hr...
# -  73/987: 00073_hr...
# -  74/987: 00074_hr...
# -  75/987: 00075_hr...
# -  76/987: 00076_hr...
# -  77/987: 00077_hr...
# -  78/987: 00078_hr...
# -  79/987: 00079_hr...
# -  80/987: 00080_hr...
# -  81/987: 00081_hr...
# -  82/987: 00082_hr...
# -  83/987: 00083_hr...
# -  84/987: 00084_hr...
# -  85/987: 00085_hr...
# -  86/987: 00086_hr...
# -  87/987: 00087_hr...
# -  88/987: 00088_hr...
# -  89/987: 00089_hr...
# -  90/987: 00090_hr...
# -  91/987: 00091_hr...
# -  92/987: 00092_hr...
# -  93/987: 00093_hr...
# -  94/987: 00094_hr...
# -  95/987: 00095_hr...
# -  96/987: 00096_hr...
# -  97/987: 00097_hr...
# -  98/987: 00098_hr...
# -  99/987: 00099_hr...
# - 100/987: 00100_hr...
# - 101/987: 00101_hr...
# - 102/987: 00102_hr...
# - 103/987: 00103_hr...
# - 104/987: 00104_hr...
# - 105/987: 00105_hr...
# - 106/987: 00106_hr...
# - 107/987: 00107_hr...
# - 108/987: 00108_hr...
# - 109/987: 00109_hr...
# - 110/987: 00110_hr...
# - 111/987: 00111_hr...
# - 112/987: 00112_hr...
# - 113/987: 00113_hr...
# - 114/987: 00114_hr...
# - 115/987: 00115_hr...
# - 116/987: 00116_hr...
# - 117/987: 00117_hr...
# - 118/987: 00118_hr...
# - 119/987: 00119_hr...
# - 120/987: 00120_hr...
# - 121/987: 00121_hr...
# - 122/987: 00122_hr...
# - 123/987: 00123_hr...
# - 124/987: 00124_hr...
# - 125/987: 00125_hr...
# - 126/987: 00126_hr...
# - 127/987: 00127_hr...
# - 128/987: 00128_hr...
# - 129/987: 00129_hr...
# - 130/987: 00130_hr...
# - 131/987: 00131_hr...
# - 132/987: 00132_hr...
# - 133/987: 00133_hr...
# - 134/987: 00134_hr...
# - 135/987: 00135_hr...
# - 136/987: 00136_hr...
# - 137/987: 00138_hr...
# - 138/987: 00144_hr...
# - 139/987: 00146_hr...
# - 140/987: 00147_hr...
# - 141/987: 00148_hr...
# - 142/987: 00149_hr...
# - 143/987: 00150_hr...
# - 144/987: 00151_hr...
# - 145/987: 00152_hr...
# - 146/987: 00153_hr...
# - 147/987: 00154_hr...
# - 148/987: 00155_hr...
# - 149/987: 00156_hr...
# - 150/987: 00157_hr...
# - 151/987: 00158_hr...
# - 152/987: 00159_hr...
# - 153/987: 00160_hr...
# - 154/987: 00161_hr...
# - 155/987: 00162_hr...
# - 156/987: 00163_hr...
# - 157/987: 00164_hr...
# - 158/987: 00165_hr...
# - 159/987: 00166_hr...
# - 160/987: 00167_hr...
# - 161/987: 00168_hr...
# - 162/987: 00169_hr...
# - 163/987: 00170_hr...
# - 164/987: 00171_hr...
# - 165/987: 00172_hr...
# - 166/987: 00173_hr...
# - 167/987: 00174_hr...
# - 168/987: 00175_hr...
# - 169/987: 00176_hr...
# - 170/987: 00177_hr...
# - 171/987: 00178_hr...
# - 172/987: 00179_hr...
# - 173/987: 00180_hr...
# - 174/987: 00181_hr...
# - 175/987: 00182_hr...
# - 176/987: 00183_hr...
# - 177/987: 00184_hr...
# - 178/987: 00185_hr...
# - 179/987: 00186_hr...
# - 180/987: 00187_hr...
# - 181/987: 00188_hr...
# - 182/987: 00189_hr...
# - 183/987: 00190_hr...
# - 184/987: 00191_hr...
# - 185/987: 00192_hr...
# - 186/987: 00193_hr...
# - 187/987: 00194_hr...
# - 188/987: 00195_hr...
# - 189/987: 00196_hr...
# - 190/987: 00197_hr...
# - 191/987: 00198_hr...
# - 192/987: 00199_hr...
# - 193/987: 00200_hr...
# - 194/987: 00201_hr...
# - 195/987: 00202_hr...
# - 196/987: 00203_hr...
# - 197/987: 00204_hr...
# - 198/987: 00205_hr...
# - 199/987: 00206_hr...
# - 200/987: 00207_hr...
# - 201/987: 00208_hr...
# - 202/987: 00209_hr...
# - 203/987: 00210_hr...
# - 204/987: 00211_hr...
# - 205/987: 00212_hr...
# - 206/987: 00213_hr...
# - 207/987: 00214_hr...
# - 208/987: 00215_hr...
# - 209/987: 00216_hr...
# - 210/987: 00217_hr...
# - 211/987: 00218_hr...
# - 212/987: 00219_hr...
# - 213/987: 00220_hr...
# - 214/987: 00221_hr...
# - 215/987: 00222_hr...
# - 216/987: 00223_hr...
# - 217/987: 00224_hr...
# - 218/987: 00225_hr...
# - 219/987: 00226_hr...
# - 220/987: 00227_hr...
# - 221/987: 00228_hr...
# - 222/987: 00229_hr...
# - 223/987: 00230_hr...
# - 224/987: 00231_hr...
# - 225/987: 00232_hr...
# - 226/987: 00233_hr...
# - 227/987: 00234_hr...
# - 228/987: 00235_hr...
# - 229/987: 00236_hr...
# - 230/987: 00237_hr...
# - 231/987: 00238_hr...
# - 232/987: 00239_hr...
# - 233/987: 00240_hr...
# - 234/987: 00241_hr...
# - 235/987: 00242_hr...
# - 236/987: 00243_hr...
# - 237/987: 00244_hr...
# - 238/987: 00245_hr...
# - 239/987: 00246_hr...
# - 240/987: 00247_hr...
# - 241/987: 00248_hr...
# - 242/987: 00249_hr...
# - 243/987: 00250_hr...
# - 244/987: 00251_hr...
# - 245/987: 00252_hr...
# - 246/987: 00253_hr...
# - 247/987: 00254_hr...
# - 248/987: 00255_hr...
# - 249/987: 00256_hr...
# - 250/987: 00257_hr...
# - 251/987: 00258_hr...
# - 252/987: 00259_hr...
# - 253/987: 00260_hr...
# - 254/987: 00261_hr...
# - 255/987: 00262_hr...
# - 256/987: 00263_hr...
# - 257/987: 00264_hr...
# - 258/987: 00265_hr...
# - 259/987: 00266_hr...
# - 260/987: 00267_hr...
# - 261/987: 00268_hr...
# - 262/987: 00269_hr...
# - 263/987: 00270_hr...
# - 264/987: 00271_hr...
# - 265/987: 00272_hr...
# - 266/987: 00273_hr...
# - 267/987: 00274_hr...
# - 268/987: 00275_hr...
# - 269/987: 00276_hr...
# - 270/987: 00277_hr...
# - 271/987: 00278_hr...
# - 272/987: 00279_hr...
# - 273/987: 00280_hr...
# - 274/987: 00281_hr...
# - 275/987: 00282_hr...
# - 276/987: 00283_hr...
# - 277/987: 00284_hr...
# - 278/987: 00285_hr...
# - 279/987: 00286_hr...
# - 280/987: 00287_hr...
# - 281/987: 00288_hr...
# - 282/987: 00289_hr...
# - 283/987: 00290_hr...
# - 284/987: 00291_hr...
# - 285/987: 00292_hr...
# - 286/987: 00293_hr...
# - 287/987: 00294_hr...
# - 288/987: 00295_hr...
# - 289/987: 00296_hr...
# - 290/987: 00297_hr...
# - 291/987: 00298_hr...
# - 292/987: 00299_hr...
# - 293/987: 00300_hr...
# - 294/987: 00301_hr...
# - 295/987: 00302_hr...
# - 296/987: 00303_hr...
# - 297/987: 00304_hr...
# - 298/987: 00305_hr...
# - 299/987: 00306_hr...
# - 300/987: 00307_hr...
# - 301/987: 00308_hr...
# - 302/987: 00309_hr...
# - 303/987: 00310_hr...
# - 304/987: 00311_hr...
# - 305/987: 00312_hr...
# - 306/987: 00313_hr...
# - 307/987: 00314_hr...
# - 308/987: 00315_hr...
# - 309/987: 00316_hr...
# - 310/987: 00317_hr...
# - 311/987: 00318_hr...
# - 312/987: 00319_hr...
# - 313/987: 00320_hr...
# - 314/987: 00321_hr...
# - 315/987: 00322_hr...
# - 316/987: 00323_hr...
# - 317/987: 00324_hr...
# - 318/987: 00325_hr...
# - 319/987: 00326_hr...
# - 320/987: 00327_hr...
# - 321/987: 00328_hr...
# - 322/987: 00329_hr...
# - 323/987: 00330_hr...
# - 324/987: 00331_hr...
# - 325/987: 00332_hr...
# - 326/987: 00333_hr...
# - 327/987: 00334_hr...
# - 328/987: 00335_hr...
# - 329/987: 00336_hr...
# - 330/987: 00337_hr...
# - 331/987: 00338_hr...
# - 332/987: 00339_hr...
# - 333/987: 00340_hr...
# - 334/987: 00341_hr...
# - 335/987: 00342_hr...
# - 336/987: 00343_hr...
# - 337/987: 00344_hr...
# - 338/987: 00345_hr...
# - 339/987: 00346_hr...
# - 340/987: 00347_hr...
# - 341/987: 00348_hr...
# - 342/987: 00349_hr...
# - 343/987: 00350_hr...
# - 344/987: 00351_hr...
# - 345/987: 00352_hr...
# - 346/987: 00353_hr...
# - 347/987: 00354_hr...
# - 348/987: 00355_hr...
# - 349/987: 00356_hr...
# - 350/987: 00357_hr...
# - 351/987: 00358_hr...
# - 352/987: 00359_hr...
# - 353/987: 00360_hr...
# - 354/987: 00361_hr...
# - 355/987: 00362_hr...
# - 356/987: 00363_hr...
# - 357/987: 00364_hr...
# - 358/987: 00365_hr...
# - 359/987: 00366_hr...
# - 360/987: 00367_hr...
# - 361/987: 00368_hr...
# - 362/987: 00369_hr...
# - 363/987: 00370_hr...
# - 364/987: 00371_hr...
# - 365/987: 00372_hr...
# - 366/987: 00373_hr...
# - 367/987: 00374_hr...
# - 368/987: 00375_hr...
# - 369/987: 00376_hr...
# - 370/987: 00377_hr...
# - 371/987: 00378_hr...
# - 372/987: 00379_hr...
# - 373/987: 00380_hr...
# - 374/987: 00381_hr...
# - 375/987: 00382_hr...
# - 376/987: 00383_hr...
# - 377/987: 00384_hr...
# - 378/987: 00385_hr...
# - 379/987: 00386_hr...
# - 380/987: 00387_hr...
# - 381/987: 00388_hr...
# - 382/987: 00389_hr...
# - 383/987: 00390_hr...
# - 384/987: 00391_hr...
# - 385/987: 00392_hr...
# - 386/987: 00393_hr...
# - 387/987: 00394_hr...
# - 388/987: 00395_hr...
# - 389/987: 00396_hr...
# - 390/987: 00397_hr...
# - 391/987: 00398_hr...
# - 392/987: 00399_hr...
# - 393/987: 00400_hr...
# - 394/987: 00401_hr...
# - 395/987: 00402_hr...
# - 396/987: 00403_hr...
# - 397/987: 00404_hr...
# - 398/987: 00405_hr...
# - 399/987: 00406_hr...
# - 400/987: 00407_hr...
# - 401/987: 00408_hr...
# - 402/987: 00409_hr...
# - 403/987: 00410_hr...
# - 404/987: 00411_hr...
# - 405/987: 00412_hr...
# - 406/987: 00413_hr...
# - 407/987: 00414_hr...
# - 408/987: 00415_hr...
# - 409/987: 00416_hr...
# - 410/987: 00417_hr...
# - 411/987: 00418_hr...
# - 412/987: 00419_hr...
# - 413/987: 00420_hr...
# - 414/987: 00421_hr...
# - 415/987: 00422_hr...
# - 416/987: 00423_hr...
# - 417/987: 00424_hr...
# - 418/987: 00425_hr...
# - 419/987: 00426_hr...
# - 420/987: 00427_hr...
# - 421/987: 00428_hr...
# - 422/987: 00429_hr...
# - 423/987: 00430_hr...
# - 424/987: 00431_hr...
# - 425/987: 00432_hr...
# - 426/987: 00433_hr...
# - 427/987: 00434_hr...
# - 428/987: 00435_hr...
# - 429/987: 00436_hr...
# - 430/987: 00437_hr...
# - 431/987: 00438_hr...
# - 432/987: 00439_hr...
# - 433/987: 00440_hr...
# - 434/987: 00441_hr...
# - 435/987: 00442_hr...
# - 436/987: 00443_hr...
# - 437/987: 00444_hr...
# - 438/987: 00445_hr...
# - 439/987: 00446_hr...
# - 440/987: 00447_hr...
# - 441/987: 00448_hr...
# - 442/987: 00449_hr...
# - 443/987: 00450_hr...
# - 444/987: 00451_hr...
# - 445/987: 00452_hr...
# - 446/987: 00453_hr...
# - 447/987: 00454_hr...
# - 448/987: 00455_hr...
# - 449/987: 00457_hr...
# - 450/987: 00460_hr...
# - 451/987: 00463_hr...
# - 452/987: 00464_hr...
# - 453/987: 00465_hr...
# - 454/987: 00466_hr...
# - 455/987: 00467_hr...
# - 456/987: 00468_hr...
# - 457/987: 00469_hr...
# - 458/987: 00470_hr...
# - 459/987: 00471_hr...
# - 460/987: 00472_hr...
# - 461/987: 00473_hr...
# - 462/987: 00474_hr...
# - 463/987: 00475_hr...
# - 464/987: 00476_hr...
# - 465/987: 00477_hr...
# - 466/987: 00478_hr...
# - 467/987: 00479_hr...
# - 468/987: 00480_hr...
# - 469/987: 00481_hr...
# - 470/987: 00482_hr...
# - 471/987: 00483_hr...
# - 472/987: 00484_hr...
# - 473/987: 00485_hr...
# - 474/987: 00486_hr...
# - 475/987: 00487_hr...
# - 476/987: 00488_hr...
# - 477/987: 00489_hr...
# - 478/987: 00490_hr...
# - 479/987: 00491_hr...
# - 480/987: 00492_hr...
# - 481/987: 00493_hr...
# - 482/987: 00494_hr...
# - 483/987: 00495_hr...
# - 484/987: 00496_hr...
# - 485/987: 00497_hr...
# - 486/987: 00498_hr...
# - 487/987: 00499_hr...
# - 488/987: 00500_hr...
# - 489/987: 00501_hr...
# - 490/987: 00502_hr...
# - 491/987: 00503_hr...
# - 492/987: 00504_hr...
# - 493/987: 00505_hr...
# - 494/987: 00506_hr...
# - 495/987: 00507_hr...
# - 496/987: 00508_hr...
# - 497/987: 00509_hr...
# - 498/987: 00510_hr...
# - 499/987: 00511_hr...
# - 500/987: 00512_hr...
# - 501/987: 00513_hr...
# - 502/987: 00514_hr...
# - 503/987: 00515_hr...
# - 504/987: 00516_hr...
# - 505/987: 00517_hr...
# - 506/987: 00518_hr...
# - 507/987: 00519_hr...
# - 508/987: 00520_hr...
# - 509/987: 00521_hr...
# - 510/987: 00522_hr...
# - 511/987: 00523_hr...
# - 512/987: 00524_hr...
# - 513/987: 00525_hr...
# - 514/987: 00526_hr...
# - 515/987: 00527_hr...
# - 516/987: 00528_hr...
# - 517/987: 00529_hr...
# - 518/987: 00530_hr...
# - 519/987: 00531_hr...
# - 520/987: 00532_hr...
# - 521/987: 00533_hr...
# - 522/987: 00534_hr...
# - 523/987: 00535_hr...
# - 524/987: 00536_hr...
# - 525/987: 00537_hr...
# - 526/987: 00538_hr...
# - 527/987: 00539_hr...
# - 528/987: 00540_hr...
# - 529/987: 00541_hr...
# - 530/987: 00542_hr...
# - 531/987: 00543_hr...
# - 532/987: 00544_hr...
# - 533/987: 00545_hr...
# - 534/987: 00546_hr...
# - 535/987: 00547_hr...
# - 536/987: 00548_hr...
# - 537/987: 00549_hr...
# - 538/987: 00550_hr...
# - 539/987: 00551_hr...
# - 540/987: 00552_hr...
# - 541/987: 00553_hr...
# - 542/987: 00554_hr...
# - 543/987: 00555_hr...
# - 544/987: 00556_hr...
# - 545/987: 00557_hr...
# - 546/987: 00558_hr...
# - 547/987: 00559_hr...
# - 548/987: 00560_hr...
# - 549/987: 00561_hr...
# - 550/987: 00562_hr...
# - 551/987: 00563_hr...
# - 552/987: 00564_hr...
# - 553/987: 00565_hr...
# - 554/987: 00566_hr...
# - 555/987: 00567_hr...
# - 556/987: 00568_hr...
# - 557/987: 00569_hr...
# - 558/987: 00570_hr...
# - 559/987: 00571_hr...
# - 560/987: 00572_hr...
# - 561/987: 00573_hr...
# - 562/987: 00574_hr...
# - 563/987: 00575_hr...
# - 564/987: 00576_hr...
# - 565/987: 00577_hr...
# - 566/987: 00578_hr...
# - 567/987: 00579_hr...
# - 568/987: 00580_hr...
# - 569/987: 00581_hr...
# - 570/987: 00582_hr...
# - 571/987: 00583_hr...
# - 572/987: 00584_hr...
# - 573/987: 00585_hr...
# - 574/987: 00586_hr...
# - 575/987: 00587_hr...
# - 576/987: 00588_hr...
# - 577/987: 00589_hr...
# - 578/987: 00590_hr...
# - 579/987: 00591_hr...
# - 580/987: 00592_hr...
# - 581/987: 00593_hr...
# - 582/987: 00594_hr...
# - 583/987: 00595_hr...
# - 584/987: 00596_hr...
# - 585/987: 00597_hr...
# - 586/987: 00598_hr...
# - 587/987: 00599_hr...
# - 588/987: 00600_hr...
# - 589/987: 00601_hr...
# - 590/987: 00602_hr...
# - 591/987: 00603_hr...
# - 592/987: 00604_hr...
# - 593/987: 00605_hr...
# - 594/987: 00606_hr...
# - 595/987: 00607_hr...
# - 596/987: 00608_hr...
# - 597/987: 00609_hr...
# - 598/987: 00610_hr...
# - 599/987: 00611_hr...
# - 600/987: 00612_hr...
# - 601/987: 00613_hr...
# - 602/987: 00614_hr...
# - 603/987: 00615_hr...
# - 604/987: 00616_hr...
# - 605/987: 00617_hr...
# - 606/987: 00618_hr...
# - 607/987: 00619_hr...
# - 608/987: 00620_hr...
# - 609/987: 00621_hr...
# - 610/987: 00622_hr...
# - 611/987: 00623_hr...
# - 612/987: 00624_hr...
# - 613/987: 00625_hr...
# - 614/987: 00626_hr...
# - 615/987: 00627_hr...
# - 616/987: 00628_hr...
# - 617/987: 00629_hr...
# - 618/987: 00630_hr...
# - 619/987: 00631_hr...
# - 620/987: 00632_hr...
# - 621/987: 00633_hr...
# - 622/987: 00634_hr...
# - 623/987: 00635_hr...
# - 624/987: 00636_hr...
# - 625/987: 00637_hr...
# - 626/987: 00638_hr...
# - 627/987: 00639_hr...
# - 628/987: 00640_hr...
# - 629/987: 00641_hr...
# - 630/987: 00642_hr...
# - 631/987: 00643_hr...
# - 632/987: 00644_hr...
# - 633/987: 00645_hr...
# - 634/987: 00646_hr...
# - 635/987: 00647_hr...
# - 636/987: 00648_hr...
# - 637/987: 00649_hr...
# - 638/987: 00650_hr...
# - 639/987: 00651_hr...
# - 640/987: 00652_hr...
# - 641/987: 00653_hr...
# - 642/987: 00654_hr...
# - 643/987: 00655_hr...
# - 644/987: 00656_hr...
# - 645/987: 00657_hr...
# - 646/987: 00658_hr...
# - 647/987: 00659_hr...
# - 648/987: 00660_hr...
# - 649/987: 00661_hr...
# - 650/987: 00662_hr...
# - 651/987: 00663_hr...
# - 652/987: 00664_hr...
# - 653/987: 00665_hr...
# - 654/987: 00666_hr...
# - 655/987: 00667_hr...
# - 656/987: 00668_hr...
# - 657/987: 00669_hr...
# - 658/987: 00670_hr...
# - 659/987: 00671_hr...
# - 660/987: 00672_hr...
# - 661/987: 00673_hr...
# - 662/987: 00674_hr...
# - 663/987: 00675_hr...
# - 664/987: 00676_hr...
# - 665/987: 00677_hr...
# - 666/987: 00678_hr...
# - 667/987: 00679_hr...
# - 668/987: 00680_hr...
# - 669/987: 00681_hr...
# - 670/987: 00682_hr...
# - 671/987: 00683_hr...
# - 672/987: 00684_hr...
# - 673/987: 00685_hr...
# - 674/987: 00686_hr...
# - 675/987: 00687_hr...
# - 676/987: 00688_hr...
# - 677/987: 00689_hr...
# - 678/987: 00690_hr...
# - 679/987: 00691_hr...
# - 680/987: 00692_hr...
# - 681/987: 00693_hr...
# - 682/987: 00694_hr...
# - 683/987: 00695_hr...
# - 684/987: 00696_hr...
# - 685/987: 00697_hr...
# - 686/987: 00698_hr...
# - 687/987: 00699_hr...
# - 688/987: 00700_hr...
# - 689/987: 00701_hr...
# - 690/987: 00702_hr...
# - 691/987: 00703_hr...
# - 692/987: 00704_hr...
# - 693/987: 00705_hr...
# - 694/987: 00706_hr...
# - 695/987: 00707_hr...
# - 696/987: 00708_hr...
# - 697/987: 00709_hr...
# - 698/987: 00710_hr...
# - 699/987: 00711_hr...
# - 700/987: 00712_hr...
# - 701/987: 00713_hr...
# - 702/987: 00714_hr...
# - 703/987: 00715_hr...
# - 704/987: 00716_hr...
# - 705/987: 00717_hr...
# - 706/987: 00718_hr...
# - 707/987: 00719_hr...
# - 708/987: 00720_hr...
# - 709/987: 00721_hr...
# - 710/987: 00722_hr...
# - 711/987: 00723_hr...
# - 712/987: 00724_hr...
# - 713/987: 00725_hr...
# - 714/987: 00726_hr...
# - 715/987: 00727_hr...
# - 716/987: 00728_hr...
# - 717/987: 00729_hr...
# - 718/987: 00730_hr...
# - 719/987: 00731_hr...
# - 720/987: 00732_hr...
# - 721/987: 00733_hr...
# - 722/987: 00734_hr...
# - 723/987: 00735_hr...
# - 724/987: 00736_hr...
# - 725/987: 00737_hr...
# - 726/987: 00738_hr...
# - 727/987: 00739_hr...
# - 728/987: 00740_hr...
# - 729/987: 00741_hr...
# - 730/987: 00742_hr...
# - 731/987: 00743_hr...
# - 732/987: 00744_hr...
# - 733/987: 00745_hr...
# - 734/987: 00746_hr...
# - 735/987: 00747_hr...
# - 736/987: 00748_hr...
# - 737/987: 00749_hr...
# - 738/987: 00750_hr...
# - 739/987: 00751_hr...
# - 740/987: 00752_hr...
# - 741/987: 00753_hr...
# - 742/987: 00754_hr...
# - 743/987: 00755_hr...
# - 744/987: 00756_hr...
# - 745/987: 00757_hr...
# - 746/987: 00758_hr...
# - 747/987: 00759_hr...
# - 748/987: 00760_hr...
# - 749/987: 00761_hr...
# - 750/987: 00762_hr...
# - 751/987: 00763_hr...
# - 752/987: 00764_hr...
# - 753/987: 00765_hr...
# - 754/987: 00766_hr...
# - 755/987: 00767_hr...
# - 756/987: 00768_hr...
# - 757/987: 00769_hr...
# - 758/987: 00770_hr...
# - 759/987: 00771_hr...
# - 760/987: 00772_hr...
# - 761/987: 00773_hr...
# - 762/987: 00774_hr...
# - 763/987: 00775_hr...
# - 764/987: 00776_hr...
# - 765/987: 00777_hr...
# - 766/987: 00778_hr...
# - 767/987: 00779_hr...
# - 768/987: 00780_hr...
# - 769/987: 00781_hr...
# - 770/987: 00782_hr...
# - 771/987: 00783_hr...
# - 772/987: 00784_hr...
# - 773/987: 00785_hr...
# - 774/987: 00786_hr...
# - 775/987: 00787_hr...
# - 776/987: 00788_hr...
# - 777/987: 00789_hr...
# - 778/987: 00790_hr...
# - 779/987: 00791_hr...
# - 780/987: 00792_hr...
# - 781/987: 00793_hr...
# - 782/987: 00794_hr...
# - 783/987: 00795_hr...
# - 784/987: 00796_hr...
# - 785/987: 00797_hr...
# - 786/987: 00798_hr...
# - 787/987: 00799_hr...
# - 788/987: 00800_hr...
# - 789/987: 00801_hr...
# - 790/987: 00802_hr...
# - 791/987: 00803_hr...
# - 792/987: 00804_hr...
# - 793/987: 00805_hr...
# - 794/987: 00806_hr...
# - 795/987: 00807_hr...
# - 796/987: 00808_hr...
# - 797/987: 00809_hr...
# - 798/987: 00810_hr...
# - 799/987: 00811_hr...
# - 800/987: 00812_hr...
# - 801/987: 00813_hr...
# - 802/987: 00814_hr...
# - 803/987: 00815_hr...
# - 804/987: 00816_hr...
# - 805/987: 00817_hr...
# - 806/987: 00818_hr...
# - 807/987: 00819_hr...
# - 808/987: 00820_hr...
# - 809/987: 00821_hr...
# - 810/987: 00822_hr...
# - 811/987: 00823_hr...
# - 812/987: 00824_hr...
# - 813/987: 00825_hr...
# - 814/987: 00826_hr...
# - 815/987: 00827_hr...
# - 816/987: 00828_hr...
# - 817/987: 00829_hr...
# - 818/987: 00830_hr...
# - 819/987: 00831_hr...
# - 820/987: 00832_hr...
# - 821/987: 00833_hr...
# - 822/987: 00834_hr...
# - 823/987: 00835_hr...
# - 824/987: 00836_hr...
# - 825/987: 00837_hr...
# - 826/987: 00838_hr...
# - 827/987: 00839_hr...
# - 828/987: 00840_hr...
# - 829/987: 00841_hr...
# - 830/987: 00842_hr...
# - 831/987: 00843_hr...
# - 832/987: 00844_hr...
# - 833/987: 00845_hr...
# - 834/987: 00846_hr...
# - 835/987: 00847_hr...
# - 836/987: 00848_hr...
# - 837/987: 00849_hr...
# - 838/987: 00850_hr...
# - 839/987: 00851_hr...
# - 840/987: 00852_hr...
# - 841/987: 00853_hr...
# - 842/987: 00854_hr...
# - 843/987: 00855_hr...
# - 844/987: 00856_hr...
# - 845/987: 00857_hr...
# - 846/987: 00858_hr...
# - 847/987: 00859_hr...
# - 848/987: 00860_hr...
# - 849/987: 00861_hr...
# - 850/987: 00862_hr...
# - 851/987: 00863_hr...
# - 852/987: 00864_hr...
# - 853/987: 00865_hr...
# - 854/987: 00866_hr...
# - 855/987: 00867_hr...
# - 856/987: 00868_hr...
# - 857/987: 00869_hr...
# - 858/987: 00870_hr...
# - 859/987: 00871_hr...
# - 860/987: 00872_hr...
# - 861/987: 00873_hr...
# - 862/987: 00874_hr...
# - 863/987: 00875_hr...
# - 864/987: 00876_hr...
# - 865/987: 00877_hr...
# - 866/987: 00878_hr...
# - 867/987: 00879_hr...
# - 868/987: 00880_hr...
# - 869/987: 00881_hr...
# - 870/987: 00882_hr...
# - 871/987: 00883_hr...
# - 872/987: 00884_hr...
# - 873/987: 00885_hr...
# - 874/987: 00886_hr...
# - 875/987: 00887_hr...
# - 876/987: 00888_hr...
# - 877/987: 00889_hr...
# - 878/987: 00890_hr...
# - 879/987: 00891_hr...
# - 880/987: 00892_hr...
# - 881/987: 00893_hr...
# - 882/987: 00894_hr...
# - 883/987: 00895_hr...
# - 884/987: 00896_hr...
# - 885/987: 00897_hr...
# - 886/987: 00898_hr...
# - 887/987: 00899_hr...
# - 888/987: 00900_hr...
# - 889/987: 00901_hr...
# - 890/987: 00902_hr...
# - 891/987: 00903_hr...
# - 892/987: 00904_hr...
# - 893/987: 00905_hr...
# - 894/987: 00906_hr...
# - 895/987: 00907_hr...
# - 896/987: 00908_hr...
# - 897/987: 00909_hr...
# - 898/987: 00910_hr...
# - 899/987: 00911_hr...
# - 900/987: 00912_hr...
# - 901/987: 00913_hr...
# - 902/987: 00914_hr...
# - 903/987: 00915_hr...
# - 904/987: 00916_hr...
# - 905/987: 00917_hr...
# - 906/987: 00918_hr...
# - 907/987: 00919_hr...
# - 908/987: 00920_hr...
# - 909/987: 00921_hr...
# - 910/987: 00922_hr...
# - 911/987: 00923_hr...
# - 912/987: 00924_hr...
# - 913/987: 00925_hr...
# - 914/987: 00926_hr...
# - 915/987: 00927_hr...
# - 916/987: 00928_hr...
# - 917/987: 00929_hr...
# - 918/987: 00930_hr...
# - 919/987: 00931_hr...
# - 920/987: 00932_hr...
# - 921/987: 00933_hr...
# - 922/987: 00934_hr...
# - 923/987: 00935_hr...
# - 924/987: 00936_hr...
# - 925/987: 00937_hr...
# - 926/987: 00938_hr...
# - 927/987: 00939_hr...
# - 928/987: 00940_hr...
# - 929/987: 00941_hr...
# - 930/987: 00942_hr...
# - 931/987: 00943_hr...
# - 932/987: 00944_hr...
# - 933/987: 00945_hr...
# - 934/987: 00946_hr...
# - 935/987: 00947_hr...
# - 936/987: 00948_hr...
# - 937/987: 00949_hr...
# - 938/987: 00950_hr...
# - 939/987: 00951_hr...
# - 940/987: 00952_hr...
# - 941/987: 00953_hr...
# - 942/987: 00954_hr...
# - 943/987: 00955_hr...
# - 944/987: 00956_hr...
# - 945/987: 00957_hr...
# - 946/987: 00958_hr...
# - 947/987: 00959_hr...
# - 948/987: 00960_hr...
# - 949/987: 00961_hr...
# - 950/987: 00962_hr...
# - 951/987: 00963_hr...
# - 952/987: 00964_hr...
# - 953/987: 00965_hr...
# - 954/987: 00966_hr...
# - 955/987: 00967_hr...
# - 956/987: 00968_hr...
# - 957/987: 00969_hr...
# - 958/987: 00970_hr...
# - 959/987: 00971_hr...
# - 960/987: 00972_hr...
# - 961/987: 00973_hr...
# - 962/987: 00974_hr...
# - 963/987: 00975_hr...
# - 964/987: 00976_hr...
# - 965/987: 00977_hr...
# - 966/987: 00978_hr...
# - 967/987: 00979_hr...
# - 968/987: 00980_hr...
# - 969/987: 00981_hr...
# - 970/987: 00982_hr...
# - 971/987: 00983_hr...
# - 972/987: 00984_hr...
# - 973/987: 00985_hr...
# - 974/987: 00986_hr...
# - 975/987: 00987_hr...
# - 976/987: 00988_hr...
# - 977/987: 00989_hr...
# - 978/987: 00990_hr...
# - 979/987: 00991_hr...
# - 980/987: 00992_hr...
# - 981/987: 00993_hr...
# - 982/987: 00994_hr...
# - 983/987: 00995_hr...
# - 984/987: 00996_hr...
# - 985/987: 00997_hr...
# - 986/987: 00998_hr...
# - 987/987: 00999_hr...

# %%
# We expect some images to be labeled for classification.
if not classification_labels:
  raise Exception('There are no labels for the data.')

# Fix an ordering of the labels
num_classes=len(LIST_OF_ALL_LABELS)

# %% [markdown]
# ---
# ## Data loading
# ---

# %%
# Split the training set into "training" and "validation" subsets, returning them as DataLoaders
training_loader, validation_loader \
  = get_training_and_validation_loaders(LIST_OF_ALL_LABELS, classification_images, classification_labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
for i,v in enumerate(validation_loader):
  # print(i, v)
  pass

  if i == 0:
    break

# %%
v[0].shape
# Out:
# torch.Size([4, 3, 425, 550])

# %%
v[1].shape
# Out:
# torch.Size([4, 11])

# %%
plot_folder=os.path.join(model_folder, "training_figures")
os.makedirs(plot_folder, exist_ok=True)

# Filename to save the final weights to
final_weights=None

# %% [markdown]
# -------
# ### Classification task
# -----

# %%
# Train the models.
if verbose:
    print('Training the models on the data...')
# Out:
# Training the models on the data...

# %%
# We expect some images to be labeled for classification.
if not classification_labels:
    raise Exception('There are no labels for the data.')

# Fix an ordering of the labels
num_classes=len(LIST_OF_ALL_LABELS)

# %%
LIST_OF_ALL_LABELS
# Out:
# ['NORM',
#  'Acute MI',
#  'Old MI',
#  'STTC',
#  'CD',
#  'HYP',
#  'PAC',
#  'PVC',
#  'AFIB/AFL',
#  'TACHY',
#  'BRADY']

# %%
from torchvision import models

# Initialize a pretrained VGG16 model
classification_model = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:07<00:00, 78.4MB/s]

# %%
# Modify the final layer
classification_model.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Dropout(p=0.5, inplace=False)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU(inplace=True)
#   (5): Dropout(p=0.5, inplace=False)
#   (6): Linear(in_features=4096, out_features=1000, bias=True)
# )

# %%
# Freeze the feature extractor layers
for param in classification_model.features.parameters():
    param.requires_grad = False

# %%
# Modify the final layer
classification_model.classifier[6] = nn.Linear(classification_model.classifier[6].in_features, num_classes)

# %%
# Move the model to the specified device
classification_model = classification_model.to(DEVICE)

# %%
# TODO : Select the best loss function
loss = nn.BCELoss() # binary cross entropy loss for multilabel classification

# TODO: Choose the optimal hyperparameters
opt = optim.Adam(classification_model.parameters(), lr=OPTIM_LR, weight_decay=OPTIM_WEIGHT_DECAY)

# TODO: Find out what does this do!
scheduler = StepLR(opt, step_size=SCHEDULER_STEP_SIZE, gamma=SCHEDULER_GAMMA)

# %%
N_loss = []
N_loss_valid = []
train_auprc = []
valid_auprc = []
train_auroc= []
valid_auroc = []
f1_train = []
f1_valid = []

# %%
do_validation = False

# %%
# Now let's train!
for epoch in range(EPOCHS):

    # Initialization of variables for plotting the progress
    N_item_sum = 0
    N_item_sum_valid = 0
    targets_train = []
    outputs_train = []
    targets_valid = []
    outputs_valid = []

    ### Training part
    if verbose:
        print(f"============================[{epoch}]============================")
    classification_model.train()
    for i, (image, label) in enumerate(training_loader): # train_dataloader
        opt.zero_grad()

        image = image.float().to(DEVICE)
        label = label.to(torch.float).to(DEVICE)
        prediction = torch.sigmoid(classification_model(image))

        # loss
        N = loss(prediction, label)
        N.backward()
        N_item = N.item()
        N_item_sum += N_item

        # gradient clipping plus optimizer
        torch.nn.utils.clip_grad_norm_(classification_model.parameters(), max_norm=10)
        opt.step()
        if verbose:
            print(f"Epoch: {epoch}, Iteration: {i}, Loss: {N_item}")

        targets_train.append(label.data.cpu().numpy()) #target[:,0]
        outputs_train.append(prediction.data.cpu().numpy())

    if do_validation:
        ### Validation part
        classification_model.eval()
        with torch.no_grad():
            for j, (image, label) in enumerate(validation_loader):
                image = image.float().to(DEVICE)
                label = label.to(torch.float).to(DEVICE)
                prediction = classification_model(image)

                N = loss(prediction, label)
                N_item = N.item()
                N_item_sum_valid += N.item()

                targets_valid.append(label.data.cpu().numpy()) #target[:,0]
                outputs_valid.append(prediction.data.cpu().numpy())
                print(f"Epoch: {epoch}, Valid Iteration: {j}, Loss: {N_item}")

        scheduler.step()

        # Logging the outputs and targets to calculate auprc and auroc
        targets_train = np.concatenate(targets_train, axis=0).T
        outputs_train = np.concatenate(outputs_train, axis=0).T
        targets_valid = np.concatenate(targets_valid, axis=0).T
        outputs_valid = np.concatenate(outputs_valid, axis=0).T

        auprc_t = average_precision_score(y_true=targets_train, y_score=outputs_train)
        auroc_t = roc_auc_score(y_true=targets_train, y_score=outputs_train)
        auprc_v = average_precision_score(y_true=targets_valid, y_score=outputs_valid)
        auroc_v = roc_auc_score(y_true=targets_valid, y_score=outputs_valid)

        train_auprc.append(auprc_t)
        train_auroc.append(auroc_t)
        valid_auprc.append(auprc_v)
        valid_auroc.append(auroc_v)

        N_loss.append(N_item_sum / i)
        N_loss_valid.append(N_item_sum_valid / j)

        # Saving loss function after each epoch so you can look on progress
        fig = plt.figure()
        plt.plot(N_loss, label="train")
        plt.plot(N_loss_valid, label="valid")
        plt.title("Loss function")
        plt.xlabel('epoch')
        plt.ylabel('loss')
        plt.grid()
        plt.legend()
        plt.savefig(os.path.join(plot_folder, "loss.png"))
        plt.close()

        fig = plt.figure()
        plt.plot(train_auprc, label="train auprc")
        plt.plot(valid_auprc, label="valid auprc")
        plt.plot(train_auroc, label="train auroc")
        plt.plot(valid_auroc, label="valid auroc")

        plt.title("AUPRC and AUROC")
        plt.xlabel('epoch')
        plt.ylabel('Performance')
        plt.grid()
        plt.legend()
        plt.savefig(os.path.join(plot_folder, "auroc_auprc.png"))
        plt.close()

    ### Save model after each epoch
    file_path = os.path.join(model_folder, "vgg16_weights_epochs_" + str(epoch) + ".pth")
    torch.save(classification_model.state_dict(), file_path)

    # If this is the last epoch, then the weights of the model will be saved to this file
    final_weights = file_path
# Out:
# ============================[0]============================
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch: 0, Iteration: 0, Loss: 0.6496692299842834
# Epoch: 0, Iteration: 1, Loss: 0.5974317789077759
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-45071ac8ae68> in <cell line: 2>()
#      19         image = image.float().to(DEVICE)
#      20         label = label.to(torch.float).to(DEVICE)
# ---> 21         prediction = torch.sigmoid(classification_model(image))
#      22
#      23         # loss
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/vgg.py in forward(self, x)
#      64
#      65     def forward(self, x: torch.Tensor) -> torch.Tensor:
# ---> 66         x = self.features(x)
#      67         x = self.avgpool(x)
#      68         x = torch.flatten(x, 1)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     458
#     459     def forward(self, input: Tensor) -> Tensor:
# --> 460         return self._conv_forward(input, self.weight, self.bias)
#     461
#     462 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     454                             weight, bias, self.stride,
#     455                             _pair(0), self.dilation, self.groups)
# --> 456         return F.conv2d(input, weight, bias, self.stride,
#     457                         self.padding, self.dilation, self.groups)
#     458
#
# KeyboardInterrupt:

# %%
# Save the models.
save_classification_model(model_folder, LIST_OF_ALL_LABELS, final_weights)

if verbose:
    print('Done.')
    print()

# %%
print_folder_sizes(model_folder)
